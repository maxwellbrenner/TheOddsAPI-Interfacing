# %%
# Updated 2024.11.02
import pandas as pd
import requests
import csv
from datetime import datetime, timedelta

# Your API Key from The Odds API
API_KEY = 'Insert API Key Here'

# Define constants for the API call
SPORT = 'mma_mixed_martial_arts'  # MMA sport key
REGIONS = 'us'  # Focus on US market
MARKETS = 'h2h'  # Only fetch head-to-head markets
ODDS_FORMAT = 'american'  # American odds format
DATE_FORMAT = 'iso'  # ISO date format for timestamps

# Base URL for the Odds API
BASE_URL = 'https://api.the-odds-api.com/v4/historical/sports'

# Function to get event dates between a start and end date with 12-hour offset
def get_event_dates_between(masterlist_df, start_date, end_date):
    """
    This function filters the masterlist for event dates between the specified start and end dates,
    applies a 12-hour offset, and returns the list of unique event dates.
    """
    # Convert input dates to datetime objects
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    # Filter masterlist for event dates within the given range
    filtered_masterlist = masterlist_df[(masterlist_df['event_date'] >= start_date) & (masterlist_df['event_date'] <= end_date)].copy()
    
    # Apply a 12-hour offset to the event dates using .loc[] to avoid the warning
    filtered_masterlist.loc[:, 'event_date'] = filtered_masterlist['event_date'] + pd.Timedelta(hours=12)
    
    # Extract unique event dates
    event_dates = filtered_masterlist['event_date'].unique()
    
    # Convert event dates back to a list and return
    return list(event_dates), len(event_dates)

# Function to get historical MMA odds for a specific timestamp
def get_historical_mma_odds(api_key, snapshot_date):
    """
    Function to get historical MMA odds for a specific timestamp.
    """
    url = f'{BASE_URL}/{SPORT}/odds'
    params = {
        'api_key': api_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'date': snapshot_date,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT
    }
    
    # Make the API request
    response = requests.get(url, params=params)
    
    if response.status_code != 200:
        print(f'Failed to get historical odds: status_code {response.status_code}, response body {response.text}')
        return None, response

    # Return the parsed JSON response and the response object to access headers
    return response.json(), response

# Function to save odds data to a CSV file
def save_odds_to_csv(odds_data, file_name='mma_odds_(2024-08-24 to 2020-06-06).csv'):
    """
    Function to save odds data to a CSV file with utf-8 encoding to handle special characters.
    """
    with open(file_name, mode='a', newline='', encoding='utf-8') as file:  # Specify utf-8 encoding
        writer = csv.writer(file)
        
        # Write header if the file is empty
        if file.tell() == 0:
            writer.writerow(['Timestamp', 'Home Team', 'Away Team', 'Commence Time', 'Bookmaker', 'Market', 'Outcome Name', 'Odds Price'])
        
        # Write odds data to the CSV file
        for event in odds_data['data']:
            for bookmaker in event['bookmakers']:
                for market in bookmaker['markets']:
                    for outcome in market['outcomes']:
                        writer.writerow([odds_data['timestamp'], 
                                         event['home_team'], 
                                         event['away_team'], 
                                         event['commence_time'], 
                                         bookmaker['title'], 
                                         market['key'], 
                                         outcome['name'], 
                                         outcome['price']])


# Function to iterate through event dates and get odds for each timestamp
def get_and_save_odds_for_dates(api_key, event_dates, file_name='mma_odds_(2024-08-24 to 2020-06-06).csv', limit=None):
    """
    Function to iterate through event dates and retrieve odds, saving them to a CSV file.
    
    Parameters:
    - api_key: The Odds API key
    - event_dates: A list of event dates with 12-hour offset
    - file_name: Name of the CSV file to save the data to
    - limit: Maximum number of timestamps to process (set to None to process all dates)
    """
    if limit:
        event_dates = event_dates[:limit]  # Apply limit if specified
    
    for i, event_date in enumerate(event_dates):  # Iterate over all timestamps if limit is None
        snapshot_date = event_date.strftime("%Y-%m-%dT%H:%M:%SZ")
        
        print(f"\nFetching odds for timestamp: {snapshot_date}")
        odds_data, response = get_historical_mma_odds(api_key, snapshot_date)
        
        if odds_data:
            # Save odds data to CSV
            save_odds_to_csv(odds_data, file_name)
            print(f"Odds saved for timestamp: {snapshot_date}")
        else:
            print(f"No data available for timestamp {snapshot_date}")

        # Print the remaining and used requests after each API call
        print(f"\nRemaining requests: {response.headers.get('x-requests-remaining', 'N/A')}")
        print(f"Used requests: {response.headers.get('x-requests-used', 'N/A')}")

def main():
    # Load masterlist CSV with date parsing
    masterlist_file = r"C:\Users\EditZ\event_masterlist (updated 09-06-2024).csv"
    masterlist_df = pd.read_csv(masterlist_file, encoding='utf-8', parse_dates=['event_date'])

    # Define date range for filtering
    start_date = '2020-06-06'
    end_date = '2024-08-24'

    # Get event dates within the range
    event_dates_list, num_events = get_event_dates_between(masterlist_df, start_date, end_date)
    print(f"There are {num_events} events between {start_date} and {end_date}.")
    print(f"Event dates (with 12-hour offset): {event_dates_list}")

    # Generate a dynamic file name based on the date range
    file_name = f'mma_odds_({start_date} to {end_date}).csv'

    # Retrieve and save odds data for the first 5 event dates
    get_and_save_odds_for_dates(API_KEY, event_dates_list, file_name=file_name, limit=5)
 

if __name__ == "__main__":
    main()
# Out:
# There are 176 events between 2020-06-06 and 2024-06-08.
# Event dates (with 12-hour offset): [Timestamp('2024-06-08 12:00:00'), Timestamp('2024-06-01 12:00:00'), Timestamp('2024-05-18 12:00:00'), Timestamp('2024-05-11 12:00:00'), Timestamp('2024-05-04 12:00:00'), Timestamp('2024-04-27 12:00:00'), Timestamp('2024-04-13 12:00:00'), Timestamp('2024-04-06 12:00:00'), Timestamp('2024-03-30 12:00:00'), Timestamp('2024-03-23 12:00:00'), Timestamp('2024-03-16 12:00:00'), Timestamp('2024-03-09 12:00:00'), Timestamp('2024-03-02 12:00:00'), Timestamp('2024-02-24 12:00:00'), Timestamp('2024-02-17 12:00:00'), Timestamp('2024-02-10 12:00:00'), Timestamp('2024-02-03 12:00:00'), Timestamp('2024-01-20 12:00:00'), Timestamp('2024-01-13 12:00:00'), Timestamp('2023-12-16 12:00:00'), Timestamp('2023-12-09 12:00:00'), Timestamp('2023-12-02 12:00:00'), Timestamp('2023-11-18 12:00:00'), Timestamp('2023-11-11 12:00:00'), Timestamp('2023-11-04 12:00:00'), Timestamp('2023-10-21 12:00:00'), Timestamp('2023-10-14 12:00:00'), Timestamp('2023-10-07 12:00:00'), Timestamp('2023-09-23 12:00:00'), Timestamp('2023-09-16 12:00:00'), Timestamp('2023-09-09 12:00:00'), Timestamp('2023-09-02 12:00:00'), Timestamp('2023-08-26 12:00:00'), Timestamp('2023-08-19 12:00:00'), Timestamp('2023-08-12 12:00:00'), Timestamp('2023-08-05 12:00:00'), Timestamp('2023-07-29 12:00:00'), Timestamp('2023-07-22 12:00:00'), Timestamp('2023-07-15 12:00:00'), Timestamp('2023-07-08 12:00:00'), Timestamp('2023-07-01 12:00:00'), Timestamp('2023-06-24 12:00:00'), Timestamp('2023-06-17 12:00:00'), Timestamp('2023-06-10 12:00:00'), Timestamp('2023-06-03 12:00:00'), Timestamp('2023-05-20 12:00:00'), Timestamp('2023-05-13 12:00:00'), Timestamp('2023-05-06 12:00:00'), Timestamp('2023-04-29 12:00:00'), Timestamp('2023-04-22 12:00:00'), Timestamp('2023-04-15 12:00:00'), Timestamp('2023-04-08 12:00:00'), Timestamp('2023-03-25 12:00:00'), Timestamp('2023-03-18 12:00:00'), Timestamp('2023-03-11 12:00:00'), Timestamp('2023-03-04 12:00:00'), Timestamp('2023-02-25 12:00:00'), Timestamp('2023-02-18 12:00:00'), Timestamp('2023-02-11 12:00:00'), Timestamp('2023-02-04 12:00:00'), Timestamp('2023-01-21 12:00:00'), Timestamp('2023-01-14 12:00:00'), Timestamp('2022-12-17 12:00:00'), Timestamp('2022-12-10 12:00:00'), Timestamp('2022-12-03 12:00:00'), Timestamp('2022-11-19 12:00:00'), Timestamp('2022-11-12 12:00:00'), Timestamp('2022-11-05 12:00:00'), Timestamp('2022-10-29 12:00:00'), Timestamp('2022-10-22 12:00:00'), Timestamp('2022-10-15 12:00:00'), Timestamp('2022-10-01 12:00:00'), Timestamp('2022-09-17 12:00:00'), Timestamp('2022-09-10 12:00:00'), Timestamp('2022-09-03 12:00:00'), Timestamp('2022-08-20 12:00:00'), Timestamp('2022-08-13 12:00:00'), Timestamp('2022-08-06 12:00:00'), Timestamp('2022-07-30 12:00:00'), Timestamp('2022-07-23 12:00:00'), Timestamp('2022-07-16 12:00:00'), Timestamp('2022-07-09 12:00:00'), Timestamp('2022-07-02 12:00:00'), Timestamp('2022-06-25 12:00:00'), Timestamp('2022-06-18 12:00:00'), Timestamp('2022-06-11 12:00:00'), Timestamp('2022-06-04 12:00:00'), Timestamp('2022-05-21 12:00:00'), Timestamp('2022-05-14 12:00:00'), Timestamp('2022-05-07 12:00:00'), Timestamp('2022-04-30 12:00:00'), Timestamp('2022-04-23 12:00:00'), Timestamp('2022-04-16 12:00:00'), Timestamp('2022-04-09 12:00:00'), Timestamp('2022-03-26 12:00:00'), Timestamp('2022-03-19 12:00:00'), Timestamp('2022-03-12 12:00:00'), Timestamp('2022-03-05 12:00:00'), Timestamp('2022-02-26 12:00:00'), Timestamp('2022-02-19 12:00:00'), Timestamp('2022-02-12 12:00:00'), Timestamp('2022-02-05 12:00:00'), Timestamp('2022-01-22 12:00:00'), Timestamp('2022-01-15 12:00:00'), Timestamp('2021-12-18 12:00:00'), Timestamp('2021-12-11 12:00:00'), Timestamp('2021-12-04 12:00:00'), Timestamp('2021-11-20 12:00:00'), Timestamp('2021-11-13 12:00:00'), Timestamp('2021-11-06 12:00:00'), Timestamp('2021-10-30 12:00:00'), Timestamp('2021-10-23 12:00:00'), Timestamp('2021-10-16 12:00:00'), Timestamp('2021-10-09 12:00:00'), Timestamp('2021-10-02 12:00:00'), Timestamp('2021-09-25 12:00:00'), Timestamp('2021-09-1 ...
#
# Fetching odds for timestamp: 2024-06-08T12:00:00Z
# Odds saved for timestamp: 2024-06-08T12:00:00Z
#
# Remaining requests: 19717
# Used requests: 283
#
# Fetching odds for timestamp: 2024-06-01T12:00:00Z
# Odds saved for timestamp: 2024-06-01T12:00:00Z
#
# Remaining requests: 19707
# Used requests: 293
#
# Fetching odds for timestamp: 2024-05-18T12:00:00Z
# Odds saved for timestamp: 2024-05-18T12:00:00Z
#
# Remaining requests: 19697
# Used requests: 303
#
# Fetching odds for timestamp: 2024-05-11T12:00:00Z
# Odds saved for timestamp: 2024-05-11T12:00:00Z
#
# Remaining requests: 19687
# Used requests: 313
#
# Fetching odds for timestamp: 2024-05-04T12:00:00Z
# Odds saved for timestamp: 2024-05-04T12:00:00Z
#
# Remaining requests: 19677
# Used requests: 323
#
# Fetching odds for timestamp: 2024-04-27T12:00:00Z
# Odds saved for timestamp: 2024-04-27T12:00:00Z
#
# Remaining requests: 19667
# Used requests: 333
#
# Fetching odds for timestamp: 2024-04-13T12:00:00Z
# Odds saved for timestamp: 2024-04-13T12:00:00Z
#
# Remaining requests: 19657
# Used requests: 343
#
# Fetching odds for timestamp: 2024-04-06T12:00:00Z
# Odds saved for timestamp: 2024-04-06T12:00:00Z
#
# Remaining requests: 19647
# Used requests: 353
#
# Fetching odds for timestamp: 2024-03-30T12:00:00Z
# Odds saved for timestamp: 2024-03-30T12:00:00Z
#
# Remaining requests: 19637
# Used requests: 363
#
# Fetching odds for timestamp: 2024-03-23T12:00:00Z
# Odds saved for timestamp: 2024-03-23T12:00:00Z
#
# Remaining requests: 19627
# Used requests: 373
#
# Fetching odds for timestamp: 2024-03-16T12:00:00Z
# Odds saved for timestamp: 2024-03-16T12:00:00Z
#
# Remaining requests: 19617
# Used requests: 383
#
# Fetching odds for timestamp: 2024-03-09T12:00:00Z
# Odds saved for timestamp: 2024-03-09T12:00:00Z
#
# Remaining requests: 19607
# Used requests: 393
#
# Fetching odds for timestamp: 2024-03-02T12:00:00Z
# Odds saved for timestamp: 2024-03-02T12:00:00Z
#
# Remaining requests: 19597
# Used requests: 403
#
# Fetching odds for timestamp: 2024-02-24T12:00:00Z
# Odds saved for timestamp: 2024-02-24T12:00:00Z
#
# Remaining requests: 19587
# Used requests: 413
#
# Fetching odds for timestamp: 2024-02-17T12:00:00Z
# Odds saved for timestamp: 2024-02-17T12:00:00Z
#
# Remaining requests: 19577
# Used requests: 423
#
# Fetching odds for timestamp: 2024-02-10T12:00:00Z
# Odds saved for timestamp: 2024-02-10T12:00:00Z
#
# Remaining requests: 19567
# Used requests: 433
#
# Fetching odds for timestamp: 2024-02-03T12:00:00Z
# Odds saved for timestamp: 2024-02-03T12:00:00Z
#
# Remaining requests: 19557
# Used requests: 443
#
# Fetching odds for timestamp: 2024-01-20T12:00:00Z
# Odds saved for timestamp: 2024-01-20T12:00:00Z
#
# Remaining requests: 19547
# Used requests: 453
#
# Fetching odds for timestamp: 2024-01-13T12:00:00Z
# Odds saved for timestamp: 2024-01-13T12:00:00Z
#
# Remaining requests: 19537
# Used requests: 463
#
# Fetching odds for timestamp: 2023-12-16T12:00:00Z
# Odds saved for timestamp: 2023-12-16T12:00:00Z
#
# Remaining requests: 19527
# Used requests: 473
#
# Fetching odds for timestamp: 2023-12-09T12:00:00Z
# Odds saved for timestamp: 2023-12-09T12:00:00Z
#
# Remaining requests: 19517
# Used requests: 483
#
# Fetching odds for timestamp: 2023-12-02T12:00:00Z
# Odds saved for timestamp: 2023-12-02T12:00:00Z
#
# Remaining requests: 19507
# Used requests: 493
#
# Fetching odds for timestamp: 2023-11-18T12:00:00Z
# Odds saved for timestamp: 2023-11-18T12:00:00Z
#
# Remaining requests: 19497
# Used requests: 503
#
# Fetching odds for timestamp: 2023-11-11T12:00:00Z
# Odds saved for timestamp: 2023-11-11T12:00:00Z
#
# Remaining requests: 19487
# Used requests: 513
#
# Fetching odds for timestamp: 2023-11-04T12:00:00Z
# Odds saved for timestamp: 2023-11-04T12:00:00Z
#
# Remaining requests: 19477
# Used requests: 523
#
# Fetching odds for timestamp: 2023-10-21T12:00:00Z
# Odds saved for timestamp: 2023-10-21T12:00:00Z
#
# Remaining requests: 19467
# Used requests: 533
#
# Fetching odds for timestamp: 2023-10-14T12:00:00Z
# Odds saved for timestamp: 2023-10-14T12:00:00Z
#
# Remaining requests: 19457
# Used requests: 543
#
# Fetching odds for timestamp: 2023-10-07T12:00:00Z
# Odds saved for timestamp: 2023-10-07T12:00:00Z
#
# Remaining requests: 19447
# Used requests: 553
#
# Fetching odds for timestamp: 2023-09-23T12:00:00Z
# Odds saved for timestamp: 2023-09-23T12:00:00Z
#
# Remaining requests: 19437
# Used requests: 563
#
# Fetching odds for timestamp: 2023-09-16T12:00:00Z
# Odds saved for timestamp: 2023-09-16T12:00:00Z
#
# Remaining requests: 19427
# Used requests: 573
#
# Fetching odds for timestamp: 2023-09-09T12:00:00Z
# Odds saved for timestamp: 2023-09-09T12:00:00Z
#
# Remaining requests: 19417
# Used requests: 583
#
# Fetching odds for timestamp: 2023-09-02T12:00:00Z
# Odds saved for timestamp: 2023-09-02T12:00:00Z
#
# Remaining requests: 19407
# Used requests: 593
#
# Fetching odds for timestamp: 2023-08-26T12:00:00Z
# Odds saved for timestamp: 2023-08-26T12:00:00Z
#
# Remaining requests: 19397
# Used requests: 603
#
# Fetching odds for timestamp: 2023-08-19T12:00:00Z
# Odds saved for timestamp: 2023-08-19T12:00:00Z
#
# Remaining requests: 19387
# Used requests: 613
#
# Fetching odds for timestamp: 2023-08-12T12:00:00Z
# Odds saved for timestamp: 2023-08-12T12:00:00Z
#
# Remaining requests: 19377
# Used requests: 623
#
# Fetching odds for timestamp: 2023-08-05T12:00:00Z
# Odds saved for timestamp: 2023-08-05T12:00:00Z
#
# Remaining requests: 19367
# Used requests: 633
#
# Fetching odds for timestamp: 2023-07-29T12:00:00Z
# Odds saved for timestamp: 2023-07-29T12:00:00Z
#
# Remaining requests: 19357
# Used requests: 643
#
# Fetching odds for timestamp: 2023-07-22T12:00:00Z
# Odds saved for timestamp: 2023-07-22T12:00:00Z
#
# Remaining requests: 19347
# Used requests: 653
#
# Fetching odds for timestamp: 2023-07-15T12:00:00Z
# Odds saved for timestamp: 2023-07-15T12:00:00Z
#
# Remaining requests: 19337
# Used requests: 663
#
# Fetching odds for timestamp: 2023-07-08T12:00:00Z
# Odds saved for timestamp: 2023-07-08T12:00:00Z
#
# Remaining requests: 19327
# Used requests: 673
#
# Fetching odds for timestamp: 2023-07-01T12:00:00Z
# Odds saved for timestamp: 2023-07-01T12:00:00Z
#
# Remaining requests: 19317
# Used requests: 683
#
# Fetching odds for timestamp: 2023-06-24T12:00:00Z
# Odds saved for timestamp: 2023-06-24T12:00:00Z
#
# Remaining requests: 19307
# Used requests: 693
#
# Fetching odds for timestamp: 2023-06-17T12:00:00Z
# Odds saved for timestamp: 2023-06-17T12:00:00Z
#
# Remaining requests: 19297
# Used requests: 703
#
# Fetching odds for timestamp: 2023-06-10T12:00:00Z
# Odds saved for timestamp: 2023-06-10T12:00:00Z
#
# Remaining requests: 19287
# Used requests: 713
#
# Fetching odds for timestamp: 2023-06-03T12:00:00Z
# Odds saved for timestamp: 2023-06-03T12:00:00Z
#
# Remaining requests: 19277
# Used requests: 723
#
# Fetching odds for timestamp: 2023-05-20T12:00:00Z
# Odds saved for timestamp: 2023-05-20T12:00:00Z
#
# Remaining requests: 19267
# Used requests: 733
#
# Fetching odds for timestamp: 2023-05-13T12:00:00Z
# Odds saved for timestamp: 2023-05-13T12:00:00Z
#
# Remaining requests: 19257
# Used requests: 743
#
# Fetching odds for timestamp: 2023-05-06T12:00:00Z
# Odds saved for timestamp: 2023-05-06T12:00:00Z
#
# Remaining requests: 19247
# Used requests: 753
#
# Fetching odds for timestamp: 2023-04-29T12:00:00Z
# Odds saved for timestamp: 2023-04-29T12:00:00Z
#
# Remaining requests: 19237
# Used requests: 763
#
# Fetching odds for timestamp: 2023-04-22T12:00:00Z
# Odds saved for timestamp: 2023-04-22T12:00:00Z
#
# Remaining requests: 19227
# Used requests: 773
#
# Fetching odds for timestamp: 2023-04-15T12:00:00Z
# Odds saved for timestamp: 2023-04-15T12:00:00Z
#
# Remaining requests: 19217
# Used requests: 783
#
# Fetching odds for timestamp: 2023-04-08T12:00:00Z
# Odds saved for timestamp: 2023-04-08T12:00:00Z
#
# Remaining requests: 19207
# Used requests: 793
#
# Fetching odds for timestamp: 2023-03-25T12:00:00Z
# Odds saved for timestamp: 2023-03-25T12:00:00Z
#
# Remaining requests: 19197
# Used requests: 803
#
# Fetching odds for timestamp: 2023-03-18T12:00:00Z
# Odds saved for timestamp: 2023-03-18T12:00:00Z
#
# Remaining requests: 19187
# Used requests: 813
#
# Fetching odds for timestamp: 2023-03-11T12:00:00Z
# Odds saved for timestamp: 2023-03-11T12:00:00Z
#
# Remaining requests: 19177
# Used requests: 823
#
# Fetching odds for timestamp: 2023-03-04T12:00:00Z
# Odds saved for timestamp: 2023-03-04T12:00:00Z
#
# Remaining requests: 19167
# Used requests: 833
#
# Fetching odds for timestamp: 2023-02-25T12:00:00Z
# Odds saved for timestamp: 2023-02-25T12:00:00Z
#
# Remaining requests: 19157
# Used requests: 843
#
# Fetching odds for timestamp: 2023-02-18T12:00:00Z
# Odds saved for timestamp: 2023-02-18T12:00:00Z
#
# Remaining requests: 19147
# Used requests: 853
#
# Fetching odds for timestamp: 2023-02-11T12:00:00Z
# Odds saved for timestamp: 2023-02-11T12:00:00Z
#
# Remaining requests: 19137
# Used requests: 863
#
# Fetching odds for timestamp: 2023-02-04T12:00:00Z
# Odds saved for timestamp: 2023-02-04T12:00:00Z
#
# Remaining requests: 19127
# Used requests: 873
#
# Fetching odds for timestamp: 2023-01-21T12:00:00Z
# Odds saved for timestamp: 2023-01-21T12:00:00Z
#
# Remaining requests: 19117
# Used requests: 883
#
# Fetching odds for timestamp: 2023-01-14T12:00:00Z
# Odds saved for timestamp: 2023-01-14T12:00:00Z
#
# Remaining requests: 19107
# Used requests: 893
#
# Fetching odds for timestamp: 2022-12-17T12:00:00Z
# Odds saved for timestamp: 2022-12-17T12:00:00Z
#
# Remaining requests: 19097
# Used requests: 903
#
# Fetching odds for timestamp: 2022-12-10T12:00:00Z
# Odds saved for timestamp: 2022-12-10T12:00:00Z
#
# Remaining requests: 19087
# Used requests: 913
#
# Fetching odds for timestamp: 2022-12-03T12:00:00Z
# Odds saved for timestamp: 2022-12-03T12:00:00Z
#
# Remaining requests: 19077
# Used requests: 923
#
# Fetching odds for timestamp: 2022-11-19T12:00:00Z
# Odds saved for timestamp: 2022-11-19T12:00:00Z
#
# Remaining requests: 19067
# Used requests: 933
#
# Fetching odds for timestamp: 2022-11-12T12:00:00Z
# Odds saved for timestamp: 2022-11-12T12:00:00Z
#
# Remaining requests: 19057
# Used requests: 943
#
# Fetching odds for timestamp: 2022-11-05T12:00:00Z
# Odds saved for timestamp: 2022-11-05T12:00:00Z
#
# Remaining requests: 19047
# Used requests: 953
#
# Fetching odds for timestamp: 2022-10-29T12:00:00Z
# Odds saved for timestamp: 2022-10-29T12:00:00Z
#
# Remaining requests: 19037
# Used requests: 963
#
# Fetching odds for timestamp: 2022-10-22T12:00:00Z
# Odds saved for timestamp: 2022-10-22T12:00:00Z
#
# Remaining requests: 19027
# Used requests: 973
#
# Fetching odds for timestamp: 2022-10-15T12:00:00Z
# Odds saved for timestamp: 2022-10-15T12:00:00Z
#
# Remaining requests: 19017
# Used requests: 983
#
# Fetching odds for timestamp: 2022-10-01T12:00:00Z
# Odds saved for timestamp: 2022-10-01T12:00:00Z
#
# Remaining requests: 19007
# Used requests: 993
#
# Fetching odds for timestamp: 2022-09-17T12:00:00Z
# Odds saved for timestamp: 2022-09-17T12:00:00Z
#
# Remaining requests: 18997
# Used requests: 1003
#
# Fetching odds for timestamp: 2022-09-10T12:00:00Z
# Odds saved for timestamp: 2022-09-10T12:00:00Z
#
# Remaining requests: 18987
# Used requests: 1013
#
# Fetching odds for timestamp: 2022-09-03T12:00:00Z
# Odds saved for timestamp: 2022-09-03T12:00:00Z
#
# Remaining requests: 18977
# Used requests: 1023
#
# Fetching odds for timestamp: 2022-08-20T12:00:00Z
# Odds saved for timestamp: 2022-08-20T12:00:00Z
#
# Remaining requests: 18967
# Used requests: 1033
#
# Fetching odds for timestamp: 2022-08-13T12:00:00Z
# Odds saved for timestamp: 2022-08-13T12:00:00Z
#
# Remaining requests: 18957
# Used requests: 1043
#
# Fetching odds for timestamp: 2022-08-06T12:00:00Z
# Odds saved for timestamp: 2022-08-06T12:00:00Z
#
# Remaining requests: 18947
# Used requests: 1053
#
# Fetching odds for timestamp: 2022-07-30T12:00:00Z
# Odds saved for timestamp: 2022-07-30T12:00:00Z
#
# Remaining requests: 18937
# Used requests: 1063
#
# Fetching odds for timestamp: 2022-07-23T12:00:00Z
# Odds saved for timestamp: 2022-07-23T12:00:00Z
#
# Remaining requests: 18927
# Used requests: 1073
#
# Fetching odds for timestamp: 2022-07-16T12:00:00Z
# Odds saved for timestamp: 2022-07-16T12:00:00Z
#
# Remaining requests: 18917
# Used requests: 1083
#
# Fetching odds for timestamp: 2022-07-09T12:00:00Z
# Odds saved for timestamp: 2022-07-09T12:00:00Z
#
# Remaining requests: 18907
# Used requests: 1093
#
# Fetching odds for timestamp: 2022-07-02T12:00:00Z
# Odds saved for timestamp: 2022-07-02T12:00:00Z
#
# Remaining requests: 18897
# Used requests: 1103
#
# Fetching odds for timestamp: 2022-06-25T12:00:00Z
# Odds saved for timestamp: 2022-06-25T12:00:00Z
#
# Remaining requests: 18887
# Used requests: 1113
#
# Fetching odds for timestamp: 2022-06-18T12:00:00Z
# Odds saved for timestamp: 2022-06-18T12:00:00Z
#
# Remaining requests: 18877
# Used requests: 1123
#
# Fetching odds for timestamp: 2022-06-11T12:00:00Z
# Odds saved for timestamp: 2022-06-11T12:00:00Z
#
# Remaining requests: 18867
# Used requests: 1133
#
# Fetching odds for timestamp: 2022-06-04T12:00:00Z
# Odds saved for timestamp: 2022-06-04T12:00:00Z
#
# Remaining requests: 18857
# Used requests: 1143
#
# Fetching odds for timestamp: 2022-05-21T12:00:00Z
# Odds saved for timestamp: 2022-05-21T12:00:00Z
#
# Remaining requests: 18847
# Used requests: 1153
#
# Fetching odds for timestamp: 2022-05-14T12:00:00Z
# Odds saved for timestamp: 2022-05-14T12:00:00Z
#
# Remaining requests: 18837
# Used requests: 1163
#
# Fetching odds for timestamp: 2022-05-07T12:00:00Z
# Odds saved for timestamp: 2022-05-07T12:00:00Z
#
# Remaining requests: 18827
# Used requests: 1173
#
# Fetching odds for timestamp: 2022-04-30T12:00:00Z
# Odds saved for timestamp: 2022-04-30T12:00:00Z
#
# Remaining requests: 18817
# Used requests: 1183
#
# Fetching odds for timestamp: 2022-04-23T12:00:00Z
# Odds saved for timestamp: 2022-04-23T12:00:00Z
#
# Remaining requests: 18807
# Used requests: 1193
#
# Fetching odds for timestamp: 2022-04-16T12:00:00Z
# Odds saved for timestamp: 2022-04-16T12:00:00Z
#
# Remaining requests: 18797
# Used requests: 1203
#
# Fetching odds for timestamp: 2022-04-09T12:00:00Z
# Odds saved for timestamp: 2022-04-09T12:00:00Z
#
# Remaining requests: 18787
# Used requests: 1213
#
# Fetching odds for timestamp: 2022-03-26T12:00:00Z
# Odds saved for timestamp: 2022-03-26T12:00:00Z
#
# Remaining requests: 18777
# Used requests: 1223
#
# Fetching odds for timestamp: 2022-03-19T12:00:00Z
# Odds saved for timestamp: 2022-03-19T12:00:00Z
#
# Remaining requests: 18767
# Used requests: 1233
#
# Fetching odds for timestamp: 2022-03-12T12:00:00Z
# Odds saved for timestamp: 2022-03-12T12:00:00Z
#
# Remaining requests: 18757
# Used requests: 1243
#
# Fetching odds for timestamp: 2022-03-05T12:00:00Z
# Odds saved for timestamp: 2022-03-05T12:00:00Z
#
# Remaining requests: 18747
# Used requests: 1253
#
# Fetching odds for timestamp: 2022-02-26T12:00:00Z
# Odds saved for timestamp: 2022-02-26T12:00:00Z
#
# Remaining requests: 18737
# Used requests: 1263
#
# Fetching odds for timestamp: 2022-02-19T12:00:00Z
# Odds saved for timestamp: 2022-02-19T12:00:00Z
#
# Remaining requests: 18727
# Used requests: 1273
#
# Fetching odds for timestamp: 2022-02-12T12:00:00Z
# Odds saved for timestamp: 2022-02-12T12:00:00Z
#
# Remaining requests: 18717
# Used requests: 1283
#
# Fetching odds for timestamp: 2022-02-05T12:00:00Z
# Odds saved for timestamp: 2022-02-05T12:00:00Z
#
# Remaining requests: 18707
# Used requests: 1293
#
# Fetching odds for timestamp: 2022-01-22T12:00:00Z
# Odds saved for timestamp: 2022-01-22T12:00:00Z
#
# Remaining requests: 18697
# Used requests: 1303
#
# Fetching odds for timestamp: 2022-01-15T12:00:00Z
# Odds saved for timestamp: 2022-01-15T12:00:00Z
#
# Remaining requests: 18687
# Used requests: 1313
#
# Fetching odds for timestamp: 2021-12-18T12:00:00Z
# Odds saved for timestamp: 2021-12-18T12:00:00Z
#
# Remaining requests: 18677
# Used requests: 1323
#
# Fetching odds for timestamp: 2021-12-11T12:00:00Z
# Odds saved for timestamp: 2021-12-11T12:00:00Z
#
# Remaining requests: 18667
# Used requests: 1333
#
# Fetching odds for timestamp: 2021-12-04T12:00:00Z
# Odds saved for timestamp: 2021-12-04T12:00:00Z
#
# Remaining requests: 18657
# Used requests: 1343
#
# Fetching odds for timestamp: 2021-11-20T12:00:00Z
# Odds saved for timestamp: 2021-11-20T12:00:00Z
#
# Remaining requests: 18647
# Used requests: 1353
#
# Fetching odds for timestamp: 2021-11-13T12:00:00Z
# Odds saved for timestamp: 2021-11-13T12:00:00Z
#
# Remaining requests: 18637
# Used requests: 1363
#
# Fetching odds for timestamp: 2021-11-06T12:00:00Z
# Odds saved for timestamp: 2021-11-06T12:00:00Z
#
# Remaining requests: 18627
# Used requests: 1373
#
# Fetching odds for timestamp: 2021-10-30T12:00:00Z
# Odds saved for timestamp: 2021-10-30T12:00:00Z
#
# Remaining requests: 18617
# Used requests: 1383
#
# Fetching odds for timestamp: 2021-10-23T12:00:00Z
# Odds saved for timestamp: 2021-10-23T12:00:00Z
#
# Remaining requests: 18607
# Used requests: 1393
#
# Fetching odds for timestamp: 2021-10-16T12:00:00Z
# Odds saved for timestamp: 2021-10-16T12:00:00Z
#
# Remaining requests: 18597
# Used requests: 1403
#
# Fetching odds for timestamp: 2021-10-09T12:00:00Z
# Odds saved for timestamp: 2021-10-09T12:00:00Z
#
# Remaining requests: 18587
# Used requests: 1413
#
# Fetching odds for timestamp: 2021-10-02T12:00:00Z
# Odds saved for timestamp: 2021-10-02T12:00:00Z
#
# Remaining requests: 18577
# Used requests: 1423
#
# Fetching odds for timestamp: 2021-09-25T12:00:00Z
# Odds saved for timestamp: 2021-09-25T12:00:00Z
#
# Remaining requests: 18567
# Used requests: 1433
#
# Fetching odds for timestamp: 2021-09-18T12:00:00Z
# Odds saved for timestamp: 2021-09-18T12:00:00Z
#
# Remaining requests: 18557
# Used requests: 1443
#
# Fetching odds for timestamp: 2021-09-04T12:00:00Z
# Odds saved for timestamp: 2021-09-04T12:00:00Z
#
# Remaining requests: 18547
# Used requests: 1453
#
# Fetching odds for timestamp: 2021-08-28T12:00:00Z
# Odds saved for timestamp: 2021-08-28T12:00:00Z
#
# Remaining requests: 18537
# Used requests: 1463
#
# Fetching odds for timestamp: 2021-08-21T12:00:00Z
# Odds saved for timestamp: 2021-08-21T12:00:00Z
#
# Remaining requests: 18527
# Used requests: 1473
#
# Fetching odds for timestamp: 2021-08-07T12:00:00Z
# Odds saved for timestamp: 2021-08-07T12:00:00Z
#
# Remaining requests: 18517
# Used requests: 1483
#
# Fetching odds for timestamp: 2021-07-31T12:00:00Z
# Odds saved for timestamp: 2021-07-31T12:00:00Z
#
# Remaining requests: 18507
# Used requests: 1493
#
# Fetching odds for timestamp: 2021-07-24T12:00:00Z
# Odds saved for timestamp: 2021-07-24T12:00:00Z
#
# Remaining requests: 18497
# Used requests: 1503
#
# Fetching odds for timestamp: 2021-07-17T12:00:00Z
# Odds saved for timestamp: 2021-07-17T12:00:00Z
#
# Remaining requests: 18487
# Used requests: 1513
#
# Fetching odds for timestamp: 2021-07-10T12:00:00Z
# Odds saved for timestamp: 2021-07-10T12:00:00Z
#
# Remaining requests: 18477
# Used requests: 1523
#
# Fetching odds for timestamp: 2021-06-26T12:00:00Z
# Odds saved for timestamp: 2021-06-26T12:00:00Z
#
# Remaining requests: 18467
# Used requests: 1533
#
# Fetching odds for timestamp: 2021-06-19T12:00:00Z
# Odds saved for timestamp: 2021-06-19T12:00:00Z
#
# Remaining requests: 18457
# Used requests: 1543
#
# Fetching odds for timestamp: 2021-06-12T12:00:00Z
# Odds saved for timestamp: 2021-06-12T12:00:00Z
#
# Remaining requests: 18447
# Used requests: 1553
#
# Fetching odds for timestamp: 2021-06-05T12:00:00Z
# Odds saved for timestamp: 2021-06-05T12:00:00Z
#
# Remaining requests: 18437
# Used requests: 1563
#
# Fetching odds for timestamp: 2021-05-22T12:00:00Z
# Odds saved for timestamp: 2021-05-22T12:00:00Z
#
# Remaining requests: 18427
# Used requests: 1573
#
# Fetching odds for timestamp: 2021-05-15T12:00:00Z
# Odds saved for timestamp: 2021-05-15T12:00:00Z
#
# Remaining requests: 18417
# Used requests: 1583
#
# Fetching odds for timestamp: 2021-05-08T12:00:00Z
# Odds saved for timestamp: 2021-05-08T12:00:00Z
#
# Remaining requests: 18407
# Used requests: 1593
#
# Fetching odds for timestamp: 2021-05-01T12:00:00Z
# Odds saved for timestamp: 2021-05-01T12:00:00Z
#
# Remaining requests: 18397
# Used requests: 1603
#
# Fetching odds for timestamp: 2021-04-24T12:00:00Z
# Odds saved for timestamp: 2021-04-24T12:00:00Z
#
# Remaining requests: 18387
# Used requests: 1613
#
# Fetching odds for timestamp: 2021-04-17T12:00:00Z
# Odds saved for timestamp: 2021-04-17T12:00:00Z
#
# Remaining requests: 18377
# Used requests: 1623
#
# Fetching odds for timestamp: 2021-04-10T12:00:00Z
# Odds saved for timestamp: 2021-04-10T12:00:00Z
#
# Remaining requests: 18367
# Used requests: 1633
#
# Fetching odds for timestamp: 2021-03-27T12:00:00Z
# Odds saved for timestamp: 2021-03-27T12:00:00Z
#
# Remaining requests: 18357
# Used requests: 1643
#
# Fetching odds for timestamp: 2021-03-20T12:00:00Z
# Odds saved for timestamp: 2021-03-20T12:00:00Z
#
# Remaining requests: 18347
# Used requests: 1653
#
# Fetching odds for timestamp: 2021-03-13T12:00:00Z
# Odds saved for timestamp: 2021-03-13T12:00:00Z
#
# Remaining requests: 18337
# Used requests: 1663
#
# Fetching odds for timestamp: 2021-03-06T12:00:00Z
# Odds saved for timestamp: 2021-03-06T12:00:00Z
#
# Remaining requests: 18327
# Used requests: 1673
#
# Fetching odds for timestamp: 2021-02-27T12:00:00Z
# Odds saved for timestamp: 2021-02-27T12:00:00Z
#
# Remaining requests: 18317
# Used requests: 1683
#
# Fetching odds for timestamp: 2021-02-20T12:00:00Z
# Odds saved for timestamp: 2021-02-20T12:00:00Z
#
# Remaining requests: 18307
# Used requests: 1693
#
# Fetching odds for timestamp: 2021-02-13T12:00:00Z
# Odds saved for timestamp: 2021-02-13T12:00:00Z
#
# Remaining requests: 18297
# Used requests: 1703
#
# Fetching odds for timestamp: 2021-02-06T12:00:00Z
# Odds saved for timestamp: 2021-02-06T12:00:00Z
#
# Remaining requests: 18287
# Used requests: 1713
#
# Fetching odds for timestamp: 2021-01-23T12:00:00Z
# Odds saved for timestamp: 2021-01-23T12:00:00Z
#
# Remaining requests: 18277
# Used requests: 1723
#
# Fetching odds for timestamp: 2021-01-20T12:00:00Z
# Odds saved for timestamp: 2021-01-20T12:00:00Z
#
# Remaining requests: 18267
# Used requests: 1733
#
# Fetching odds for timestamp: 2021-01-16T12:00:00Z
# Odds saved for timestamp: 2021-01-16T12:00:00Z
#
# Remaining requests: 18257
# Used requests: 1743
#
# Fetching odds for timestamp: 2020-12-19T12:00:00Z
# Odds saved for timestamp: 2020-12-19T12:00:00Z
#
# Remaining requests: 18247
# Used requests: 1753
#
# Fetching odds for timestamp: 2020-12-12T12:00:00Z
# Odds saved for timestamp: 2020-12-12T12:00:00Z
#
# Remaining requests: 18237
# Used requests: 1763
#
# Fetching odds for timestamp: 2020-12-05T12:00:00Z
# Odds saved for timestamp: 2020-12-05T12:00:00Z
#
# Remaining requests: 18227
# Used requests: 1773
#
# Fetching odds for timestamp: 2020-11-28T12:00:00Z
# Odds saved for timestamp: 2020-11-28T12:00:00Z
#
# Remaining requests: 18217
# Used requests: 1783
#
# Fetching odds for timestamp: 2020-11-21T12:00:00Z
# Odds saved for timestamp: 2020-11-21T12:00:00Z
#
# Remaining requests: 18207
# Used requests: 1793
#
# Fetching odds for timestamp: 2020-11-14T12:00:00Z
# Odds saved for timestamp: 2020-11-14T12:00:00Z
#
# Remaining requests: 18197
# Used requests: 1803
#
# Fetching odds for timestamp: 2020-11-07T12:00:00Z
# Odds saved for timestamp: 2020-11-07T12:00:00Z
#
# Remaining requests: 18187
# Used requests: 1813
#
# Fetching odds for timestamp: 2020-10-31T12:00:00Z
# Odds saved for timestamp: 2020-10-31T12:00:00Z
#
# Remaining requests: 18177
# Used requests: 1823
#
# Fetching odds for timestamp: 2020-10-24T12:00:00Z
# Odds saved for timestamp: 2020-10-24T12:00:00Z
#
# Remaining requests: 18167
# Used requests: 1833
#
# Fetching odds for timestamp: 2020-10-17T12:00:00Z
# Odds saved for timestamp: 2020-10-17T12:00:00Z
#
# Remaining requests: 18157
# Used requests: 1843
#
# Fetching odds for timestamp: 2020-10-10T12:00:00Z
# Odds saved for timestamp: 2020-10-10T12:00:00Z
#
# Remaining requests: 18147
# Used requests: 1853
#
# Fetching odds for timestamp: 2020-10-03T12:00:00Z
# Odds saved for timestamp: 2020-10-03T12:00:00Z
#
# Remaining requests: 18137
# Used requests: 1863
#
# Fetching odds for timestamp: 2020-09-26T12:00:00Z
# Odds saved for timestamp: 2020-09-26T12:00:00Z
#
# Remaining requests: 18127
# Used requests: 1873
#
# Fetching odds for timestamp: 2020-09-19T12:00:00Z
# Odds saved for timestamp: 2020-09-19T12:00:00Z
#
# Remaining requests: 18117
# Used requests: 1883
#
# Fetching odds for timestamp: 2020-09-12T12:00:00Z
# Odds saved for timestamp: 2020-09-12T12:00:00Z
#
# Remaining requests: 18107
# Used requests: 1893
#
# Fetching odds for timestamp: 2020-09-05T12:00:00Z
# Odds saved for timestamp: 2020-09-05T12:00:00Z
#
# Remaining requests: 18097
# Used requests: 1903
#
# Fetching odds for timestamp: 2020-08-29T12:00:00Z
# Odds saved for timestamp: 2020-08-29T12:00:00Z
#
# Remaining requests: 18087
# Used requests: 1913
#
# Fetching odds for timestamp: 2020-08-22T12:00:00Z
# Odds saved for timestamp: 2020-08-22T12:00:00Z
#
# Remaining requests: 18077
# Used requests: 1923
#
# Fetching odds for timestamp: 2020-08-15T12:00:00Z
# Odds saved for timestamp: 2020-08-15T12:00:00Z
#
# Remaining requests: 18067
# Used requests: 1933
#
# Fetching odds for timestamp: 2020-08-08T12:00:00Z
# Odds saved for timestamp: 2020-08-08T12:00:00Z
#
# Remaining requests: 18057
# Used requests: 1943
#
# Fetching odds for timestamp: 2020-08-01T12:00:00Z
# Odds saved for timestamp: 2020-08-01T12:00:00Z
#
# Remaining requests: 18047
# Used requests: 1953
#
# Fetching odds for timestamp: 2020-07-25T12:00:00Z
# Odds saved for timestamp: 2020-07-25T12:00:00Z
#
# Remaining requests: 18037
# Used requests: 1963
#
# Fetching odds for timestamp: 2020-07-18T12:00:00Z
# Odds saved for timestamp: 2020-07-18T12:00:00Z
#
# Remaining requests: 18027
# Used requests: 1973
#
# Fetching odds for timestamp: 2020-07-15T12:00:00Z
# Odds saved for timestamp: 2020-07-15T12:00:00Z
#
# Remaining requests: 18017
# Used requests: 1983
#
# Fetching odds for timestamp: 2020-07-11T12:00:00Z
# Odds saved for timestamp: 2020-07-11T12:00:00Z
#
# Remaining requests: 18007
# Used requests: 1993
#
# Fetching odds for timestamp: 2020-06-27T12:00:00Z
# Odds saved for timestamp: 2020-06-27T12:00:00Z
#
# Remaining requests: 17997
# Used requests: 2003
#
# Fetching odds for timestamp: 2020-06-20T12:00:00Z
# Odds saved for timestamp: 2020-06-20T12:00:00Z
#
# Remaining requests: 17987
# Used requests: 2013
#
# Fetching odds for timestamp: 2020-06-13T12:00:00Z
# Odds saved for timestamp: 2020-06-13T12:00:00Z
#
# Remaining requests: 17977
# Used requests: 2023
#
# Fetching odds for timestamp: 2020-06-06T12:00:00Z
# Odds saved for timestamp: 2020-06-06T12:00:00Z
#
# Remaining requests: 17967
# Used requests: 2033

# %%
import csv
from collections import defaultdict
from statistics import mean

# Define a function to load odds data from the CSV file and structure it for easy display
def load_odds_from_csv(file_name):
    fights_with_odds = defaultdict(lambda: {
        'Event Date': None,
        'Fighter A': None,
        'Fighter B': None,
        'Fighter A Odds': [],
        'Fighter B Odds': [],
        'Fighter A Avg Odds': None,
        'Fighter B Avg Odds': None,
        'Fighter A Best Odds': None,
        'Fighter B Best Odds': None
    })
    
    # Read odds data from CSV
    with open(file_name, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            event_key = (row['Home Team'], row['Away Team'], row['Commence Time'])
            
            # Initialize event information if not already set
            if not fights_with_odds[event_key]['Event Date']:
                fights_with_odds[event_key]['Event Date'] = row['Commence Time']
                fights_with_odds[event_key]['Fighter A'] = row['Home Team']
                fights_with_odds[event_key]['Fighter B'] = row['Away Team']
            
            # Collect odds data for each fighter
            odds_info = {
                'Bookmaker': row['Bookmaker'],
                'Odds Price': float(row['Odds Price'])
            }
            if row['Outcome Name'] == fights_with_odds[event_key]['Fighter A']:
                fights_with_odds[event_key]['Fighter A Odds'].append(odds_info)
            elif row['Outcome Name'] == fights_with_odds[event_key]['Fighter B']:
                fights_with_odds[event_key]['Fighter B Odds'].append(odds_info)
    
    # Calculate average and best odds for each fighter
    for fight, details in fights_with_odds.items():
        if details['Fighter A Odds']:
            odds_prices = [odds['Odds Price'] for odds in details['Fighter A Odds']]
            details['Fighter A Avg Odds'] = mean(odds_prices)
            details['Fighter A Best Odds'] = min(details['Fighter A Odds'], key=lambda x: x['Odds Price'])
        
        if details['Fighter B Odds']:
            odds_prices = [odds['Odds Price'] for odds in details['Fighter B Odds']]
            details['Fighter B Avg Odds'] = mean(odds_prices)
            details['Fighter B Best Odds'] = min(details['Fighter B Odds'], key=lambda x: x['Odds Price'])
    
    return fights_with_odds

# Display function to format and print the structured odds data
def display_fights_with_odds(fights_with_odds):
    for event_key, fight in fights_with_odds.items():
        print(f"Event Date: {fight['Event Date']}")
        print(f"Fighter A: {fight['Fighter A']}")
        
        # Fighter A odds information
        if fight['Fighter A Odds']:
            print("  Fighter A Odds:")
            for odds in fight['Fighter A Odds']:
                print(f"    Bookmaker: {odds['Bookmaker']}, Odds Price: {odds['Odds Price']}")
            print(f"  Fighter A Avg Odds: {fight['Fighter A Avg Odds']}")
            print(f"  Fighter A Best Odds: {fight['Fighter A Best Odds']['Odds Price']} (Bookmaker: {fight['Fighter A Best Odds']['Bookmaker']})")
        else:
            print("  No odds available for Fighter A")
        
        print(f"\nFighter B: {fight['Fighter B']}")
        
        # Fighter B odds information
        if fight['Fighter B Odds']:
            print("  Fighter B Odds:")
            for odds in fight['Fighter B Odds']:
                print(f"    Bookmaker: {odds['Bookmaker']}, Odds Price: {odds['Odds Price']}")
            print(f"  Fighter B Avg Odds: {fight['Fighter B Avg Odds']}")
            print(f"  Fighter B Best Odds: {fight['Fighter B Best Odds']['Odds Price']} (Bookmaker: {fight['Fighter B Best Odds']['Bookmaker']})")
        else:
            print("  No odds available for Fighter B")
        
        print("\n" + "=" * 50 + "\n")

# Load odds from the CSV and display them
file_name = r"C:\Users\EditZ\UFC Research\New Pipeline\(DONT TOUCH) mma_odds_(2024-08-24 to 2020-06-06).csv"
fights_with_odds = load_odds_from_csv(file_name)
display_fights_with_odds(fights_with_odds)
# Out:
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Albert Odzimkowski
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -185.0
#     Bookmaker: LowVig.ag, Odds Price: -175.0
#   Fighter A Avg Odds: -180.0
#   Fighter A Best Odds: -185.0 (Bookmaker: Bovada)
#
# Fighter B: David Hosek
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 140.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#   Fighter B Avg Odds: 142.5
#   Fighter B Best Odds: 140.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Krystian Blezien
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -155.0
#     Bookmaker: LowVig.ag, Odds Price: -150.0
#   Fighter A Avg Odds: -152.5
#   Fighter A Best Odds: -155.0 (Bookmaker: Bovada)
#
# Fighter B: Alvin Lowenski
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 120.0
#     Bookmaker: LowVig.ag, Odds Price: 120.0
#   Fighter B Avg Odds: 120.0
#   Fighter B Best Odds: 120.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Oleksii Polischuk
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -145.0
#     Bookmaker: LowVig.ag, Odds Price: -135.0
#   Fighter A Avg Odds: -140.0
#   Fighter A Best Odds: -145.0 (Bookmaker: Bovada)
#
# Fighter B: Bruno Azevedo
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 110.0
#     Bookmaker: LowVig.ag, Odds Price: 105.0
#   Fighter B Avg Odds: 107.5
#   Fighter B Best Odds: 105.0 (Bookmaker: LowVig.ag)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Igor Michaliszyn
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -525.0
#     Bookmaker: LowVig.ag, Odds Price: -500.0
#   Fighter A Avg Odds: -512.5
#   Fighter A Best Odds: -525.0 (Bookmaker: Bovada)
#
# Fighter B: Oton Jasse
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 340.0
#     Bookmaker: LowVig.ag, Odds Price: 375.0
#   Fighter B Avg Odds: 357.5
#   Fighter B Best Odds: 340.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Sergiusz Zajac
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: 115.0
#     Bookmaker: LowVig.ag, Odds Price: 120.0
#   Fighter A Avg Odds: 117.5
#   Fighter A Best Odds: 115.0 (Bookmaker: Bovada)
#
# Fighter B: Kleber Silva
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: -150.0
#     Bookmaker: LowVig.ag, Odds Price: -150.0
#   Fighter B Avg Odds: -150.0
#   Fighter B Best Odds: -150.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Konrad Rusinski
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -205.0
#     Bookmaker: LowVig.ag, Odds Price: -210.0
#   Fighter A Avg Odds: -207.5
#   Fighter A Best Odds: -210.0 (Bookmaker: LowVig.ag)
#
# Fighter B: Michal Guzik
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 155.0
#     Bookmaker: LowVig.ag, Odds Price: 170.0
#   Fighter B Avg Odds: 162.5
#   Fighter B Best Odds: 155.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Marcin Krakowiak
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -155.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#   Fighter A Avg Odds: -162.5
#   Fighter A Best Odds: -170.0 (Bookmaker: LowVig.ag)
#
# Fighter B: Muslim Tulshaev
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 120.0
#     Bookmaker: LowVig.ag, Odds Price: 140.0
#   Fighter B Avg Odds: 130.0
#   Fighter B Best Odds: 120.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-24T17:00:00Z
# Fighter A: Szymon Bajor
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -260.0
#     Bookmaker: LowVig.ag, Odds Price: -225.0
#   Fighter A Avg Odds: -242.5
#   Fighter A Best Odds: -260.0 (Bookmaker: Bovada)
#
# Fighter B: Matheus Scheffel
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 190.0
#     Bookmaker: LowVig.ag, Odds Price: 185.0
#   Fighter B Avg Odds: 187.5
#   Fighter B Best Odds: 185.0 (Bookmaker: LowVig.ag)
#
# ==================================================
#
# Event Date: 2024-08-24T23:00:00Z
# Fighter A: Wang Cong
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -1200.0
#     Bookmaker: BetOnline.ag, Odds Price: -1200.0
#     Bookmaker: LowVig.ag, Odds Price: -1205.0
#     Bookmaker: FanDuel, Odds Price: -1200.0
#     Bookmaker: BetRivers, Odds Price: -1250.0
#     Bookmaker: BetMGM, Odds Price: -1200.0
#     Bookmaker: Bovada, Odds Price: -1400.0
#     Bookmaker: BetUS, Odds Price: -1200.0
#     Bookmaker: Caesars, Odds Price: -1200.0
#     Bookmaker: DraftKings, Odds Price: -800.0
#     Bookmaker: BetOnline.ag, Odds Price: -800.0
#     Bookmaker: LowVig.ag, Odds Price: -800.0
#     Bookmaker: FanDuel, Odds Price: -670.0
#     Bookmaker: BetRivers, Odds Price: -670.0
#     Bookmaker: BetMGM, Odds Price: -800.0
#     Bookmaker: Bovada, Odds Price: -750.0
#     Bookmaker: BetUS, Odds Price: -800.0
#   Fighter A Avg Odds: -1008.5294117647059
#   Fighter A Best Odds: -1400.0 (Bookmaker: Bovada)
#
# Fighter B: Victoria Leonardo
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 750.0
#     Bookmaker: BetOnline.ag, Odds Price: 750.0
#     Bookmaker: LowVig.ag, Odds Price: 750.0
#     Bookmaker: FanDuel, Odds Price: 750.0
#     Bookmaker: BetRivers, Odds Price: 750.0
#     Bookmaker: BetMGM, Odds Price: 750.0
#     Bookmaker: Bovada, Odds Price: 750.0
#     Bookmaker: BetUS, Odds Price: 650.0
#     Bookmaker: Caesars, Odds Price: 750.0
#     Bookmaker: DraftKings, Odds Price: 550.0
#     Bookmaker: BetOnline.ag, Odds Price: 550.0
#     Bookmaker: LowVig.ag, Odds Price: 550.0
#     Bookmaker: FanDuel, Odds Price: 430.0
#     Bookmaker: BetRivers, Odds Price: 480.0
#     Bookmaker: BetMGM, Odds Price: 550.0
#     Bookmaker: Bovada, Odds Price: 500.0
#     Bookmaker: BetUS, Odds Price: 500.0
#   Fighter B Avg Odds: 632.9411764705883
#   Fighter B Best Odds: 430.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-08-24T23:45:00Z
# Fighter A: Zygimantas Ramaska
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 124.0
#     Bookmaker: FanDuel, Odds Price: 130.0
#     Bookmaker: LowVig.ag, Odds Price: 125.0
#     Bookmaker: BetOnline.ag, Odds Price: 125.0
#     Bookmaker: BetUS, Odds Price: 115.0
#     Bookmaker: BetMGM, Odds Price: 125.0
#     Bookmaker: Bovada, Odds Price: 125.0
#     Bookmaker: Caesars, Odds Price: 125.0
#     Bookmaker: BetRivers, Odds Price: 135.0
#   Fighter A Avg Odds: 125.44444444444444
#   Fighter A Best Odds: 115.0 (Bookmaker: BetUS)
#
# Fighter B: Nathan Fletcher
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -148.0
#     Bookmaker: FanDuel, Odds Price: -154.0
#     Bookmaker: LowVig.ag, Odds Price: -145.0
#     Bookmaker: BetOnline.ag, Odds Price: -145.0
#     Bookmaker: BetUS, Odds Price: -145.0
#     Bookmaker: BetMGM, Odds Price: -150.0
#     Bookmaker: Bovada, Odds Price: -145.0
#     Bookmaker: Caesars, Odds Price: -150.0
#     Bookmaker: BetRivers, Odds Price: -167.0
#   Fighter B Avg Odds: -149.88888888888889
#   Fighter B Best Odds: -167.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2024-08-25T00:10:00Z
# Fighter A: Jacqueline Cavalcanti
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -230.0
#     Bookmaker: LowVig.ag, Odds Price: -222.0
#     Bookmaker: BetOnline.ag, Odds Price: -222.0
#     Bookmaker: FanDuel, Odds Price: -215.0
#     Bookmaker: BetRivers, Odds Price: -245.0
#     Bookmaker: BetMGM, Odds Price: -225.0
#     Bookmaker: Bovada, Odds Price: -230.0
#     Bookmaker: BetUS, Odds Price: -220.0
#     Bookmaker: Caesars, Odds Price: -225.0
#   Fighter A Avg Odds: -226.0
#   Fighter A Best Odds: -245.0 (Bookmaker: BetRivers)
#
# Fighter B: Josiane Nunes
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 190.0
#     Bookmaker: LowVig.ag, Odds Price: 187.0
#     Bookmaker: BetOnline.ag, Odds Price: 187.0
#     Bookmaker: FanDuel, Odds Price: 180.0
#     Bookmaker: BetRivers, Odds Price: 190.0
#     Bookmaker: BetMGM, Odds Price: 180.0
#     Bookmaker: Bovada, Odds Price: 190.0
#     Bookmaker: BetUS, Odds Price: 180.0
#     Bookmaker: Caesars, Odds Price: 185.0
#   Fighter B Avg Odds: 185.44444444444446
#   Fighter B Best Odds: 180.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-08-25T00:40:00Z
# Fighter A: James Llontop
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 180.0
#     Bookmaker: LowVig.ag, Odds Price: 175.0
#     Bookmaker: BetOnline.ag, Odds Price: 175.0
#     Bookmaker: FanDuel, Odds Price: 176.0
#     Bookmaker: BetRivers, Odds Price: 170.0
#     Bookmaker: BetMGM, Odds Price: 175.0
#     Bookmaker: Bovada, Odds Price: 185.0
#     Bookmaker: BetUS, Odds Price: 170.0
#     Bookmaker: Caesars, Odds Price: 175.0
#   Fighter A Avg Odds: 175.66666666666666
#   Fighter A Best Odds: 170.0 (Bookmaker: BetRivers)
#
# Fighter B: Viacheslav Borshchev
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -218.0
#     Bookmaker: LowVig.ag, Odds Price: -205.0
#     Bookmaker: BetOnline.ag, Odds Price: -205.0
#     Bookmaker: FanDuel, Odds Price: -210.0
#     Bookmaker: BetRivers, Odds Price: -215.0
#     Bookmaker: BetMGM, Odds Price: -210.0
#     Bookmaker: Bovada, Odds Price: -225.0
#     Bookmaker: BetUS, Odds Price: -205.0
#     Bookmaker: Caesars, Odds Price: -210.0
#   Fighter B Avg Odds: -211.44444444444446
#   Fighter B Best Odds: -225.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-08-25T01:10:00Z
# Fighter A: Jose Daniel Medina
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 455.0
#     Bookmaker: LowVig.ag, Odds Price: 450.0
#     Bookmaker: BetOnline.ag, Odds Price: 450.0
#     Bookmaker: FanDuel, Odds Price: 440.0
#     Bookmaker: BetRivers, Odds Price: 430.0
#     Bookmaker: BetMGM, Odds Price: 425.0
#     Bookmaker: BetUS, Odds Price: 425.0
#     Bookmaker: Caesars, Odds Price: 460.0
#     Bookmaker: Bovada, Odds Price: 430.0
#   Fighter A Avg Odds: 440.55555555555554
#   Fighter A Best Odds: 425.0 (Bookmaker: BetMGM)
#
# Fighter B: Zachary Reese
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -625.0
#     Bookmaker: LowVig.ag, Odds Price: -625.0
#     Bookmaker: BetOnline.ag, Odds Price: -625.0
#     Bookmaker: FanDuel, Odds Price: -590.0
#     Bookmaker: BetRivers, Odds Price: -590.0
#     Bookmaker: BetMGM, Odds Price: -600.0
#     Bookmaker: BetUS, Odds Price: -625.0
#     Bookmaker: Caesars, Odds Price: -650.0
#     Bookmaker: Bovada, Odds Price: -625.0
#   Fighter B Avg Odds: -617.2222222222222
#   Fighter B Best Odds: -650.0 (Bookmaker: Caesars)
#
# ==================================================
#
# Event Date: 2024-08-25T01:45:00Z
# Fighter A: Dennis Buzukja
#   Fighter A Odds:
#     Bookmaker: LowVig.ag, Odds Price: 140.0
#     Bookmaker: BetOnline.ag, Odds Price: 140.0
#     Bookmaker: FanDuel, Odds Price: 134.0
#     Bookmaker: Bovada, Odds Price: 133.0
#     Bookmaker: DraftKings, Odds Price: 130.0
#     Bookmaker: BetUS, Odds Price: 130.0
#     Bookmaker: BetRivers, Odds Price: 116.0
#     Bookmaker: BetMGM, Odds Price: 120.0
#     Bookmaker: Caesars, Odds Price: 122.0
#   Fighter A Avg Odds: 129.44444444444446
#   Fighter A Best Odds: 116.0 (Bookmaker: BetRivers)
#
# Fighter B: Francis Marshall
#   Fighter B Odds:
#     Bookmaker: LowVig.ag, Odds Price: -160.0
#     Bookmaker: BetOnline.ag, Odds Price: -160.0
#     Bookmaker: FanDuel, Odds Price: -158.0
#     Bookmaker: Bovada, Odds Price: -155.0
#     Bookmaker: DraftKings, Odds Price: -155.0
#     Bookmaker: BetUS, Odds Price: -160.0
#     Bookmaker: BetRivers, Odds Price: -143.0
#     Bookmaker: BetMGM, Odds Price: -145.0
#     Bookmaker: Caesars, Odds Price: -145.0
#   Fighter B Avg Odds: -153.44444444444446
#   Fighter B Best Odds: -160.0 (Bookmaker: LowVig.ag)
#
# ==================================================
#
# Event Date: 2024-08-25T02:00:00Z
# Fighter A: Michael Morales
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -900.0
#     Bookmaker: LowVig.ag, Odds Price: -901.0
#     Bookmaker: BetOnline.ag, Odds Price: -900.0
#     Bookmaker: FanDuel, Odds Price: -850.0
#     Bookmaker: BetRivers, Odds Price: -910.0
#     Bookmaker: BetMGM, Odds Price: -900.0
#     Bookmaker: Bovada, Odds Price: -950.0
#     Bookmaker: BetUS, Odds Price: -900.0
#     Bookmaker: Caesars, Odds Price: -800.0
#     Bookmaker: DraftKings, Odds Price: -575.0
#     Bookmaker: LowVig.ag, Odds Price: -599.0
#     Bookmaker: BetOnline.ag, Odds Price: -600.0
#     Bookmaker: FanDuel, Odds Price: -520.0
#     Bookmaker: BetRivers, Odds Price: -530.0
#     Bookmaker: BetMGM, Odds Price: -600.0
#     Bookmaker: Bovada, Odds Price: -575.0
#     Bookmaker: BetUS, Odds Price: -600.0
#   Fighter A Avg Odds: -741.7647058823529
#   Fighter A Best Odds: -950.0 (Bookmaker: Bovada)
#
# Fighter B: Neil Magny
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 600.0
#     Bookmaker: LowVig.ag, Odds Price: 600.0
#     Bookmaker: BetOnline.ag, Odds Price: 600.0
#     Bookmaker: FanDuel, Odds Price: 590.0
#     Bookmaker: BetRivers, Odds Price: 600.0
#     Bookmaker: BetMGM, Odds Price: 600.0
#     Bookmaker: Bovada, Odds Price: 600.0
#     Bookmaker: BetUS, Odds Price: 550.0
#     Bookmaker: Caesars, Odds Price: 550.0
#     Bookmaker: DraftKings, Odds Price: 425.0
#     Bookmaker: LowVig.ag, Odds Price: 425.0
#     Bookmaker: BetOnline.ag, Odds Price: 425.0
#     Bookmaker: FanDuel, Odds Price: 350.0
#     Bookmaker: BetRivers, Odds Price: 390.0
#     Bookmaker: BetMGM, Odds Price: 425.0
#     Bookmaker: Bovada, Odds Price: 400.0
#     Bookmaker: BetUS, Odds Price: 400.0
#   Fighter B Avg Odds: 501.7647058823529
#   Fighter B Best Odds: 350.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-08-25T02:00:00Z
# Fighter A: Ryan Loder
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: 120.0
#     Bookmaker: BetOnline.ag, Odds Price: 140.0
#     Bookmaker: LowVig.ag, Odds Price: 140.0
#     Bookmaker: BetRivers, Odds Price: 128.0
#     Bookmaker: Bovada, Odds Price: 130.0
#     Bookmaker: FanDuel, Odds Price: 142.0
#     Bookmaker: DraftKings, Odds Price: 136.0
#     Bookmaker: Caesars, Odds Price: 140.0
#     Bookmaker: BetMGM, Odds Price: 135.0
#   Fighter A Avg Odds: 134.55555555555554
#   Fighter A Best Odds: 120.0 (Bookmaker: BetUS)
#
# Fighter B: Robert Valentin
#   Fighter B Odds:
#     Bookmaker: BetUS, Odds Price: -150.0
#     Bookmaker: BetOnline.ag, Odds Price: -160.0
#     Bookmaker: LowVig.ag, Odds Price: -160.0
#     Bookmaker: BetRivers, Odds Price: -159.0
#     Bookmaker: Bovada, Odds Price: -150.0
#     Bookmaker: FanDuel, Odds Price: -168.0
#     Bookmaker: DraftKings, Odds Price: -162.0
#     Bookmaker: Caesars, Odds Price: -165.0
#     Bookmaker: BetMGM, Odds Price: -165.0
#   Fighter B Avg Odds: -159.88888888888889
#   Fighter B Best Odds: -168.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-08-25T02:15:00Z
# Fighter A: Edmen Shahbazyan
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -345.0
#     Bookmaker: LowVig.ag, Odds Price: -315.0
#     Bookmaker: BetOnline.ag, Odds Price: -315.0
#     Bookmaker: FanDuel, Odds Price: -360.0
#     Bookmaker: BetRivers, Odds Price: -305.0
#     Bookmaker: BetMGM, Odds Price: -350.0
#     Bookmaker: Bovada, Odds Price: -360.0
#     Bookmaker: BetUS, Odds Price: -315.0
#     Bookmaker: Caesars, Odds Price: -340.0
#   Fighter A Avg Odds: -333.8888888888889
#   Fighter A Best Odds: -360.0 (Bookmaker: FanDuel)
#
# Fighter B: Gerald Meerschaert
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 275.0
#     Bookmaker: LowVig.ag, Odds Price: 265.0
#     Bookmaker: BetOnline.ag, Odds Price: 265.0
#     Bookmaker: FanDuel, Odds Price: 290.0
#     Bookmaker: BetRivers, Odds Price: 235.0
#     Bookmaker: BetMGM, Odds Price: 270.0
#     Bookmaker: Bovada, Odds Price: 280.0
#     Bookmaker: BetUS, Odds Price: 240.0
#     Bookmaker: Caesars, Odds Price: 265.0
#   Fighter B Avg Odds: 265.0
#   Fighter B Best Odds: 235.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2024-08-25T03:00:00Z
# Fighter A: Jared Cannonier
#   Fighter A Odds:
#     Bookmaker: Caesars, Odds Price: 225.0
#     Bookmaker: BetRivers, Odds Price: 200.0
#     Bookmaker: LowVig.ag, Odds Price: 215.0
#     Bookmaker: BetOnline.ag, Odds Price: 215.0
#     Bookmaker: FanDuel, Odds Price: 200.0
#     Bookmaker: DraftKings, Odds Price: 215.0
#     Bookmaker: Bovada, Odds Price: 215.0
#     Bookmaker: BetMGM, Odds Price: 220.0
#     Bookmaker: BetUS, Odds Price: 205.0
#     Bookmaker: BetRivers, Odds Price: 132.0
#     Bookmaker: LowVig.ag, Odds Price: 135.0
#     Bookmaker: BetOnline.ag, Odds Price: 135.0
#     Bookmaker: FanDuel, Odds Price: 130.0
#     Bookmaker: DraftKings, Odds Price: 136.0
#     Bookmaker: Bovada, Odds Price: 142.0
#     Bookmaker: BetMGM, Odds Price: 130.0
#     Bookmaker: BetUS, Odds Price: 125.0
#   Fighter A Avg Odds: 175.0
#   Fighter A Best Odds: 125.0 (Bookmaker: BetUS)
#
# Fighter B: Caio Borralho
#   Fighter B Odds:
#     Bookmaker: Caesars, Odds Price: -275.0
#     Bookmaker: BetRivers, Odds Price: -250.0
#     Bookmaker: LowVig.ag, Odds Price: -255.0
#     Bookmaker: BetOnline.ag, Odds Price: -255.0
#     Bookmaker: FanDuel, Odds Price: -245.0
#     Bookmaker: DraftKings, Odds Price: -265.0
#     Bookmaker: Bovada, Odds Price: -260.0
#     Bookmaker: BetMGM, Odds Price: -275.0
#     Bookmaker: BetUS, Odds Price: -255.0
#     Bookmaker: BetRivers, Odds Price: -165.0
#     Bookmaker: LowVig.ag, Odds Price: -155.0
#     Bookmaker: BetOnline.ag, Odds Price: -155.0
#     Bookmaker: FanDuel, Odds Price: -166.0
#     Bookmaker: DraftKings, Odds Price: -162.0
#     Bookmaker: Bovada, Odds Price: -168.0
#     Bookmaker: BetMGM, Odds Price: -155.0
#     Bookmaker: BetUS, Odds Price: -155.0
#   Fighter B Avg Odds: -212.7058823529412
#   Fighter B Best Odds: -275.0 (Bookmaker: Caesars)
#
# ==================================================
#
# Event Date: 2024-08-25T03:15:00Z
# Fighter A: Kaan Ofli
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 164.0
#     Bookmaker: FanDuel, Odds Price: 168.0
#     Bookmaker: LowVig.ag, Odds Price: 175.0
#     Bookmaker: BetOnline.ag, Odds Price: 175.0
#     Bookmaker: BetUS, Odds Price: 155.0
#     Bookmaker: BetMGM, Odds Price: 170.0
#     Bookmaker: Bovada, Odds Price: 168.0
#     Bookmaker: Caesars, Odds Price: 165.0
#     Bookmaker: BetRivers, Odds Price: 163.0
#   Fighter A Avg Odds: 167.0
#   Fighter A Best Odds: 155.0 (Bookmaker: BetUS)
#
# Fighter B: Mairon Santos
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -198.0
#     Bookmaker: FanDuel, Odds Price: -200.0
#     Bookmaker: LowVig.ag, Odds Price: -205.0
#     Bookmaker: BetOnline.ag, Odds Price: -205.0
#     Bookmaker: BetUS, Odds Price: -185.0
#     Bookmaker: BetMGM, Odds Price: -210.0
#     Bookmaker: Bovada, Odds Price: -198.0
#     Bookmaker: Caesars, Odds Price: -195.0
#     Bookmaker: BetRivers, Odds Price: -205.0
#   Fighter B Avg Odds: -200.11111111111111
#   Fighter B Best Odds: -210.0 (Bookmaker: BetMGM)
#
# ==================================================
#
# Event Date: 2024-08-25T04:15:00Z
# Fighter A: Angela Hill
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 114.0
#     Bookmaker: LowVig.ag, Odds Price: 110.0
#     Bookmaker: BetOnline.ag, Odds Price: 110.0
#     Bookmaker: FanDuel, Odds Price: 108.0
#     Bookmaker: BetRivers, Odds Price: 105.0
#     Bookmaker: BetMGM, Odds Price: 105.0
#     Bookmaker: Bovada, Odds Price: 115.0
#     Bookmaker: BetUS, Odds Price: 100.0
#   Fighter A Avg Odds: 108.375
#   Fighter A Best Odds: 100.0 (Bookmaker: BetUS)
#
# Fighter B: Tabatha Ricci
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -135.0
#     Bookmaker: LowVig.ag, Odds Price: -130.0
#     Bookmaker: BetOnline.ag, Odds Price: -130.0
#     Bookmaker: FanDuel, Odds Price: -126.0
#     Bookmaker: BetRivers, Odds Price: -127.0
#     Bookmaker: BetMGM, Odds Price: -125.0
#     Bookmaker: Bovada, Odds Price: -135.0
#     Bookmaker: BetUS, Odds Price: -130.0
#   Fighter B Avg Odds: -129.75
#   Fighter B Best Odds: -135.0 (Bookmaker: DraftKings)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Chris Padilla
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: 200.0
#     Bookmaker: Bovada, Odds Price: 215.0
#     Bookmaker: DraftKings, Odds Price: 205.0
#     Bookmaker: BetRivers, Odds Price: 195.0
#     Bookmaker: LowVig.ag, Odds Price: 210.0
#     Bookmaker: BetOnline.ag, Odds Price: 210.0
#     Bookmaker: FanDuel, Odds Price: 200.0
#     Bookmaker: Caesars, Odds Price: 205.0
#   Fighter A Avg Odds: 205.0
#   Fighter A Best Odds: 195.0 (Bookmaker: BetRivers)
#
# Fighter B: Zhu Rong
#   Fighter B Odds:
#     Bookmaker: BetUS, Odds Price: -250.0
#     Bookmaker: Bovada, Odds Price: -260.0
#     Bookmaker: DraftKings, Odds Price: -250.0
#     Bookmaker: BetRivers, Odds Price: -250.0
#     Bookmaker: LowVig.ag, Odds Price: -250.0
#     Bookmaker: BetOnline.ag, Odds Price: -250.0
#     Bookmaker: FanDuel, Odds Price: -265.0
#     Bookmaker: Caesars, Odds Price: -250.0
#   Fighter B Avg Odds: -253.125
#   Fighter B Best Odds: -265.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Gilbert Burns
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 142.0
#     Bookmaker: FanDuel, Odds Price: 136.0
#     Bookmaker: Caesars, Odds Price: 143.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: Bovada, Odds Price: 140.0
#     Bookmaker: BetRivers, Odds Price: 138.0
#     Bookmaker: BetUS, Odds Price: 140.0
#     Bookmaker: BetMGM, Odds Price: 140.0
#   Fighter A Avg Odds: 141.0
#   Fighter A Best Odds: 136.0 (Bookmaker: FanDuel)
#
# Fighter B: Sean Brady
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -170.0
#     Bookmaker: FanDuel, Odds Price: -174.0
#     Bookmaker: Caesars, Odds Price: -170.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: BetOnline.ag, Odds Price: -170.0
#     Bookmaker: Bovada, Odds Price: -165.0
#     Bookmaker: BetRivers, Odds Price: -175.0
#     Bookmaker: BetUS, Odds Price: -170.0
#     Bookmaker: BetMGM, Odds Price: -165.0
#   Fighter B Avg Odds: -169.88888888888889
#   Fighter B Best Odds: -175.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Natalia Silva
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -265.0
#     Bookmaker: LowVig.ag, Odds Price: -260.0
#     Bookmaker: BetOnline.ag, Odds Price: -260.0
#     Bookmaker: BetRivers, Odds Price: -278.0
#     Bookmaker: BetUS, Odds Price: -265.0
#     Bookmaker: Bovada, Odds Price: -245.0
#     Bookmaker: FanDuel, Odds Price: -290.0
#     Bookmaker: BetMGM, Odds Price: -275.0
#     Bookmaker: Caesars, Odds Price: -270.0
#   Fighter A Avg Odds: -267.55555555555554
#   Fighter A Best Odds: -290.0 (Bookmaker: FanDuel)
#
# Fighter B: Jessica Andrade
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 215.0
#     Bookmaker: LowVig.ag, Odds Price: 220.0
#     Bookmaker: BetOnline.ag, Odds Price: 220.0
#     Bookmaker: BetRivers, Odds Price: 215.0
#     Bookmaker: BetUS, Odds Price: 215.0
#     Bookmaker: Bovada, Odds Price: 205.0
#     Bookmaker: FanDuel, Odds Price: 215.0
#     Bookmaker: BetMGM, Odds Price: 210.0
#     Bookmaker: Caesars, Odds Price: 220.0
#   Fighter B Avg Odds: 215.0
#   Fighter B Best Odds: 205.0 (Bookmaker: Bovada)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Kyle Nelson
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: 130.0
#     Bookmaker: LowVig.ag, Odds Price: 140.0
#     Bookmaker: Bovada, Odds Price: 142.0
#     Bookmaker: BetOnline.ag, Odds Price: 140.0
#     Bookmaker: BetRivers, Odds Price: 140.0
#     Bookmaker: DraftKings, Odds Price: 140.0
#     Bookmaker: FanDuel, Odds Price: 140.0
#     Bookmaker: BetMGM, Odds Price: 135.0
#     Bookmaker: Caesars, Odds Price: 145.0
#   Fighter A Avg Odds: 139.11111111111111
#   Fighter A Best Odds: 130.0 (Bookmaker: BetUS)
#
# Fighter B: Steve Garcia Jr.
#   Fighter B Odds:
#     Bookmaker: BetUS, Odds Price: -160.0
#     Bookmaker: LowVig.ag, Odds Price: -160.0
#     Bookmaker: Bovada, Odds Price: -168.0
#     Bookmaker: BetOnline.ag, Odds Price: -160.0
#     Bookmaker: BetRivers, Odds Price: -177.0
#     Bookmaker: DraftKings, Odds Price: -166.0
#     Bookmaker: FanDuel, Odds Price: -180.0
#     Bookmaker: BetMGM, Odds Price: -165.0
#     Bookmaker: Caesars, Odds Price: -175.0
#   Fighter B Avg Odds: -167.88888888888889
#   Fighter B Best Odds: -180.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Ovince St. Preux
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 245.0
#     Bookmaker: LowVig.ag, Odds Price: 240.0
#     Bookmaker: BetOnline.ag, Odds Price: 240.0
#     Bookmaker: BetRivers, Odds Price: 215.0
#     Bookmaker: BetUS, Odds Price: 220.0
#     Bookmaker: Bovada, Odds Price: 230.0
#     Bookmaker: FanDuel, Odds Price: 200.0
#     Bookmaker: BetMGM, Odds Price: 230.0
#     Bookmaker: Caesars, Odds Price: 240.0
#   Fighter A Avg Odds: 228.88888888888889
#   Fighter A Best Odds: 200.0 (Bookmaker: FanDuel)
#
# Fighter B: Ryan Spann
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -305.0
#     Bookmaker: LowVig.ag, Odds Price: -280.0
#     Bookmaker: BetOnline.ag, Odds Price: -280.0
#     Bookmaker: BetRivers, Odds Price: -278.0
#     Bookmaker: BetUS, Odds Price: -280.0
#     Bookmaker: Bovada, Odds Price: -280.0
#     Bookmaker: FanDuel, Odds Price: -265.0
#     Bookmaker: BetMGM, Odds Price: -300.0
#     Bookmaker: Caesars, Odds Price: -300.0
#   Fighter B Avg Odds: -285.3333333333333
#   Fighter B Best Odds: -305.0 (Bookmaker: DraftKings)
#
# ==================================================
#
# Event Date: 2024-09-07T19:00:00Z
# Fighter A: Yanal Ashmoz
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: LowVig.ag, Odds Price: -106.0
#     Bookmaker: BetOnline.ag, Odds Price: -106.0
#     Bookmaker: BetRivers, Odds Price: -117.0
#     Bookmaker: BetUS, Odds Price: -115.0
#     Bookmaker: Bovada, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -115.0
#     Bookmaker: BetMGM, Odds Price: -105.0
#     Bookmaker: Caesars, Odds Price: -105.0
#   Fighter A Avg Odds: -109.88888888888889
#   Fighter A Best Odds: -117.0 (Bookmaker: BetRivers)
#
# Fighter B: Trevor Peek
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: LowVig.ag, Odds Price: -114.0
#     Bookmaker: BetOnline.ag, Odds Price: -114.0
#     Bookmaker: BetRivers, Odds Price: -107.0
#     Bookmaker: BetUS, Odds Price: -115.0
#     Bookmaker: Bovada, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -111.0
#     Bookmaker: BetMGM, Odds Price: -115.0
#     Bookmaker: Caesars, Odds Price: -115.0
#   Fighter B Avg Odds: -112.33333333333333
#   Fighter B Best Odds: -115.0 (Bookmaker: BetUS)
#
# ==================================================
#
# Event Date: 2024-09-07T20:00:00Z
# Fighter A: Andre Lima
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: BetRivers, Odds Price: -107.0
#     Bookmaker: Bovada, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -113.0
#     Bookmaker: Caesars, Odds Price: -110.0
#     Bookmaker: BetMGM, Odds Price: -110.0
#   Fighter A Avg Odds: -110.0
#   Fighter A Best Odds: -113.0 (Bookmaker: FanDuel)
#
# Fighter B: Felipe Dos Santos
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: BetRivers, Odds Price: -117.0
#     Bookmaker: Bovada, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -113.0
#     Bookmaker: Caesars, Odds Price: -110.0
#     Bookmaker: BetMGM, Odds Price: -110.0
#   Fighter B Avg Odds: -111.66666666666667
#   Fighter B Best Odds: -117.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2024-09-07T20:15:00Z
# Fighter A: Andre Petroski
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -258.0
#     Bookmaker: LowVig.ag, Odds Price: -275.0
#     Bookmaker: BetOnline.ag, Odds Price: -275.0
#     Bookmaker: BetRivers, Odds Price: -305.0
#     Bookmaker: BetUS, Odds Price: -280.0
#     Bookmaker: Bovada, Odds Price: -270.0
#     Bookmaker: FanDuel, Odds Price: -265.0
#     Bookmaker: BetMGM, Odds Price: -275.0
#     Bookmaker: Caesars, Odds Price: -275.0
#   Fighter A Avg Odds: -275.3333333333333
#   Fighter A Best Odds: -305.0 (Bookmaker: BetRivers)
#
# Fighter B: Dylan Budka
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 210.0
#     Bookmaker: LowVig.ag, Odds Price: 235.0
#     Bookmaker: BetOnline.ag, Odds Price: 235.0
#     Bookmaker: BetRivers, Odds Price: 240.0
#     Bookmaker: BetUS, Odds Price: 220.0
#     Bookmaker: Bovada, Odds Price: 220.0
#     Bookmaker: FanDuel, Odds Price: 200.0
#     Bookmaker: BetMGM, Odds Price: 220.0
#     Bookmaker: Caesars, Odds Price: 225.0
#   Fighter B Avg Odds: 222.77777777777777
#   Fighter B Best Odds: 200.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-07T21:45:00Z
# Fighter A: Isaac Dulgarian
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -1800.0
#     Bookmaker: BetRivers, Odds Price: -1667.0
#     Bookmaker: BetUS, Odds Price: -2500.0
#     Bookmaker: Bovada, Odds Price: -1900.0
#     Bookmaker: FanDuel, Odds Price: -1800.0
#     Bookmaker: BetMGM, Odds Price: -2500.0
#     Bookmaker: Caesars, Odds Price: -2000.0
#   Fighter A Avg Odds: -2023.857142857143
#   Fighter A Best Odds: -2500.0 (Bookmaker: BetUS)
#
# Fighter B: Brendon Marotte
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 1000.0
#     Bookmaker: BetRivers, Odds Price: 950.0
#     Bookmaker: BetUS, Odds Price: 900.0
#     Bookmaker: Bovada, Odds Price: 900.0
#     Bookmaker: FanDuel, Odds Price: 800.0
#     Bookmaker: BetMGM, Odds Price: 1050.0
#     Bookmaker: Caesars, Odds Price: 1000.0
#   Fighter B Avg Odds: 942.8571428571429
#   Fighter B Best Odds: 800.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-07T22:15:00Z
# Fighter A: Jaqueline Amorim
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -345.0
#     Bookmaker: LowVig.ag, Odds Price: -315.0
#     Bookmaker: BetOnline.ag, Odds Price: -315.0
#     Bookmaker: BetRivers, Odds Price: -420.0
#     Bookmaker: BetUS, Odds Price: -315.0
#     Bookmaker: Bovada, Odds Price: -330.0
#     Bookmaker: FanDuel, Odds Price: -390.0
#     Bookmaker: BetMGM, Odds Price: -350.0
#     Bookmaker: Caesars, Odds Price: -350.0
#   Fighter A Avg Odds: -347.77777777777777
#   Fighter A Best Odds: -420.0 (Bookmaker: BetRivers)
#
# Fighter B: Vanessa Demopoulos
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 275.0
#     Bookmaker: LowVig.ag, Odds Price: 265.0
#     Bookmaker: BetOnline.ag, Odds Price: 265.0
#     Bookmaker: BetRivers, Odds Price: 310.0
#     Bookmaker: BetUS, Odds Price: 240.0
#     Bookmaker: Bovada, Odds Price: 265.0
#     Bookmaker: FanDuel, Odds Price: 280.0
#     Bookmaker: BetMGM, Odds Price: 260.0
#     Bookmaker: Caesars, Odds Price: 275.0
#   Fighter B Avg Odds: 270.55555555555554
#   Fighter B Best Odds: 240.0 (Bookmaker: BetUS)
#
# ==================================================
#
# Event Date: 2024-09-07T23:00:00Z
# Fighter A: Matt Schnell
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 410.0
#     Bookmaker: LowVig.ag, Odds Price: 400.0
#     Bookmaker: BetOnline.ag, Odds Price: 400.0
#     Bookmaker: BetRivers, Odds Price: 370.0
#     Bookmaker: BetUS, Odds Price: 375.0
#     Bookmaker: Bovada, Odds Price: 355.0
#     Bookmaker: FanDuel, Odds Price: 300.0
#     Bookmaker: BetMGM, Odds Price: 400.0
#     Bookmaker: Caesars, Odds Price: 380.0
#   Fighter A Avg Odds: 376.6666666666667
#   Fighter A Best Odds: 300.0 (Bookmaker: FanDuel)
#
# Fighter B: Alessandro Costa
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -550.0
#     Bookmaker: LowVig.ag, Odds Price: -549.0
#     Bookmaker: BetOnline.ag, Odds Price: -550.0
#     Bookmaker: BetRivers, Odds Price: -500.0
#     Bookmaker: BetUS, Odds Price: -550.0
#     Bookmaker: Bovada, Odds Price: -490.0
#     Bookmaker: FanDuel, Odds Price: -430.0
#     Bookmaker: BetMGM, Odds Price: -550.0
#     Bookmaker: Caesars, Odds Price: -500.0
#   Fighter B Avg Odds: -518.7777777777778
#   Fighter B Best Odds: -550.0 (Bookmaker: DraftKings)
#
# ==================================================
#
# Event Date: 2024-09-07T23:00:00Z
# Fighter A: Yi Zha
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 190.0
#     Bookmaker: FanDuel, Odds Price: 186.0
#     Bookmaker: Bovada, Odds Price: 175.0
#   Fighter A Avg Odds: 183.66666666666666
#   Fighter A Best Odds: 175.0 (Bookmaker: Bovada)
#
# Fighter B: Gabriel Santos
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -230.0
#     Bookmaker: FanDuel, Odds Price: -245.0
#     Bookmaker: Bovada, Odds Price: -230.0
#   Fighter B Avg Odds: -235.0
#   Fighter B Best Odds: -245.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Raul Rosas Jr
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -575.0
#     Bookmaker: LowVig.ag, Odds Price: -599.0
#     Bookmaker: BetOnline.ag, Odds Price: -600.0
#     Bookmaker: FanDuel, Odds Price: -530.0
#     Bookmaker: Bovada, Odds Price: -575.0
#   Fighter A Avg Odds: -575.8
#   Fighter A Best Odds: -600.0 (Bookmaker: BetOnline.ag)
#
# Fighter B: Aori Qileng
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 425.0
#     Bookmaker: LowVig.ag, Odds Price: 425.0
#     Bookmaker: BetOnline.ag, Odds Price: 425.0
#     Bookmaker: FanDuel, Odds Price: 360.0
#     Bookmaker: Bovada, Odds Price: 400.0
#   Fighter B Avg Odds: 407.0
#   Fighter B Best Odds: 360.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Daniel Zellhuber
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -180.0
#     Bookmaker: LowVig.ag, Odds Price: -180.0
#     Bookmaker: BetOnline.ag, Odds Price: -180.0
#     Bookmaker: FanDuel, Odds Price: -188.0
#     Bookmaker: Bovada, Odds Price: -175.0
#     Bookmaker: Caesars, Odds Price: -180.0
#   Fighter A Avg Odds: -180.5
#   Fighter A Best Odds: -188.0 (Bookmaker: FanDuel)
#
# Fighter B: Esteban Ribovics
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 150.0
#     Bookmaker: LowVig.ag, Odds Price: 155.0
#     Bookmaker: BetOnline.ag, Odds Price: 155.0
#     Bookmaker: FanDuel, Odds Price: 146.0
#     Bookmaker: Bovada, Odds Price: 150.0
#     Bookmaker: Caesars, Odds Price: 150.0
#   Fighter B Avg Odds: 151.0
#   Fighter B Best Odds: 146.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Edgar Chairez
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -148.0
#     Bookmaker: LowVig.ag, Odds Price: -150.0
#     Bookmaker: BetOnline.ag, Odds Price: -150.0
#     Bookmaker: FanDuel, Odds Price: -158.0
#     Bookmaker: Bovada, Odds Price: -138.0
#     Bookmaker: Caesars, Odds Price: -150.0
#     Bookmaker: DraftKings, Odds Price: -148.0
#     Bookmaker: LowVig.ag, Odds Price: -150.0
#     Bookmaker: BetOnline.ag, Odds Price: -150.0
#     Bookmaker: DraftKings, Odds Price: -135.0
#     Bookmaker: LowVig.ag, Odds Price: -135.0
#     Bookmaker: BetOnline.ag, Odds Price: -135.0
#   Fighter A Avg Odds: -145.58333333333334
#   Fighter A Best Odds: -158.0 (Bookmaker: FanDuel)
#
# Fighter B: Kevin Borjas
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 124.0
#     Bookmaker: LowVig.ag, Odds Price: 130.0
#     Bookmaker: BetOnline.ag, Odds Price: 130.0
#     Bookmaker: FanDuel, Odds Price: 124.0
#     Bookmaker: Bovada, Odds Price: 117.0
#     Bookmaker: Caesars, Odds Price: 125.0
#     Bookmaker: DraftKings, Odds Price: 124.0
#     Bookmaker: LowVig.ag, Odds Price: 130.0
#     Bookmaker: BetOnline.ag, Odds Price: 130.0
#     Bookmaker: DraftKings, Odds Price: 114.0
#     Bookmaker: LowVig.ag, Odds Price: 115.0
#     Bookmaker: BetOnline.ag, Odds Price: 115.0
#   Fighter B Avg Odds: 123.16666666666667
#   Fighter B Best Odds: 114.0 (Bookmaker: DraftKings)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Manuel Torres
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 124.0
#     Bookmaker: LowVig.ag, Odds Price: 125.0
#     Bookmaker: BetOnline.ag, Odds Price: 125.0
#     Bookmaker: FanDuel, Odds Price: 124.0
#     Bookmaker: Bovada, Odds Price: 133.0
#     Bookmaker: Caesars, Odds Price: 122.0
#   Fighter A Avg Odds: 125.5
#   Fighter A Best Odds: 122.0 (Bookmaker: Caesars)
#
# Fighter B: Ignacio Bahamondes
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -148.0
#     Bookmaker: LowVig.ag, Odds Price: -145.0
#     Bookmaker: BetOnline.ag, Odds Price: -145.0
#     Bookmaker: FanDuel, Odds Price: -158.0
#     Bookmaker: Bovada, Odds Price: -155.0
#     Bookmaker: Caesars, Odds Price: -145.0
#   Fighter B Avg Odds: -149.33333333333334
#   Fighter B Best Odds: -158.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Irene Aldana
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 110.0
#     Bookmaker: LowVig.ag, Odds Price: 110.0
#     Bookmaker: BetOnline.ag, Odds Price: 110.0
#     Bookmaker: FanDuel, Odds Price: 104.0
#     Bookmaker: Bovada, Odds Price: 100.0
#     Bookmaker: Caesars, Odds Price: 105.0
#   Fighter A Avg Odds: 106.5
#   Fighter A Best Odds: 100.0 (Bookmaker: Bovada)
#
# Fighter B: Norma Dumont
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -130.0
#     Bookmaker: LowVig.ag, Odds Price: -130.0
#     Bookmaker: BetOnline.ag, Odds Price: -130.0
#     Bookmaker: FanDuel, Odds Price: -132.0
#     Bookmaker: Bovada, Odds Price: -120.0
#     Bookmaker: Caesars, Odds Price: -125.0
#   Fighter B Avg Odds: -127.83333333333333
#   Fighter B Best Odds: -132.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Yazmin Jauregui
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -375.0
#     Bookmaker: LowVig.ag, Odds Price: -370.0
#     Bookmaker: BetOnline.ag, Odds Price: -370.0
#     Bookmaker: FanDuel, Odds Price: -400.0
#     Bookmaker: Bovada, Odds Price: -390.0
#     Bookmaker: Caesars, Odds Price: -380.0
#   Fighter A Avg Odds: -380.8333333333333
#   Fighter A Best Odds: -400.0 (Bookmaker: FanDuel)
#
# Fighter B: Ketlen Souza
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 295.0
#     Bookmaker: LowVig.ag, Odds Price: 305.0
#     Bookmaker: BetOnline.ag, Odds Price: 305.0
#     Bookmaker: FanDuel, Odds Price: 285.0
#     Bookmaker: Bovada, Odds Price: 295.0
#     Bookmaker: Caesars, Odds Price: 300.0
#   Fighter B Avg Odds: 297.5
#   Fighter B Best Odds: 285.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-14T23:00:00Z
# Fighter A: Ronaldo Rodriguez
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -170.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: FanDuel, Odds Price: -172.0
#     Bookmaker: BetOnline.ag, Odds Price: -170.0
#     Bookmaker: Caesars, Odds Price: -175.0
#   Fighter A Avg Odds: -171.4
#   Fighter A Best Odds: -175.0 (Bookmaker: Caesars)
#
# Fighter B: Ode Osbourne
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 142.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: FanDuel, Odds Price: 134.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: Caesars, Odds Price: 135.0
#   Fighter B Avg Odds: 140.2
#   Fighter B Best Odds: 134.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-15T02:00:00Z
# Fighter A: Brian Ortega
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 142.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: BetRivers, Odds Price: 145.0
#     Bookmaker: FanDuel, Odds Price: 140.0
#     Bookmaker: Caesars, Odds Price: 143.0
#     Bookmaker: Bovada, Odds Price: 145.0
#     Bookmaker: DraftKings, Odds Price: 136.0
#     Bookmaker: LowVig.ag, Odds Price: 140.0
#     Bookmaker: BetOnline.ag, Odds Price: 140.0
#     Bookmaker: BetRivers, Odds Price: 140.0
#     Bookmaker: FanDuel, Odds Price: 136.0
#     Bookmaker: DraftKings, Odds Price: 142.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: BetRivers, Odds Price: 140.0
#     Bookmaker: FanDuel, Odds Price: 136.0
#   Fighter A Avg Odds: 141.47058823529412
#   Fighter A Best Odds: 136.0 (Bookmaker: DraftKings)
#
# Fighter B: Diego Lopes
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -170.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: BetOnline.ag, Odds Price: -170.0
#     Bookmaker: BetRivers, Odds Price: -182.0
#     Bookmaker: FanDuel, Odds Price: -180.0
#     Bookmaker: Caesars, Odds Price: -170.0
#     Bookmaker: Bovada, Odds Price: -170.0
#     Bookmaker: DraftKings, Odds Price: -162.0
#     Bookmaker: LowVig.ag, Odds Price: -160.0
#     Bookmaker: BetOnline.ag, Odds Price: -160.0
#     Bookmaker: BetRivers, Odds Price: -175.0
#     Bookmaker: FanDuel, Odds Price: -174.0
#     Bookmaker: DraftKings, Odds Price: -170.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: BetOnline.ag, Odds Price: -170.0
#     Bookmaker: BetRivers, Odds Price: -175.0
#     Bookmaker: FanDuel, Odds Price: -174.0
#   Fighter B Avg Odds: -170.7058823529412
#   Fighter B Best Odds: -182.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2024-09-15T02:30:00Z
# Fighter A: Alexa Grasso
#   Fighter A Odds:
#     Bookmaker: BetOnline.ag, Odds Price: -115.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -115.0
#     Bookmaker: Caesars, Odds Price: -115.0
#     Bookmaker: DraftKings, Odds Price: -115.0
#     Bookmaker: FanDuel, Odds Price: -118.0
#     Bookmaker: Bovada, Odds Price: -112.0
#     Bookmaker: BetOnline.ag, Odds Price: -115.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -115.0
#     Bookmaker: DraftKings, Odds Price: -115.0
#     Bookmaker: FanDuel, Odds Price: -111.0
#     Bookmaker: BetOnline.ag, Odds Price: -115.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -115.0
#     Bookmaker: Caesars, Odds Price: -115.0
#     Bookmaker: DraftKings, Odds Price: -115.0
#     Bookmaker: FanDuel, Odds Price: -111.0
#     Bookmaker: BetOnline.ag, Odds Price: -115.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -115.0
#     Bookmaker: Caesars, Odds Price: -115.0
#     Bookmaker: DraftKings, Odds Price: -105.0
#     Bookmaker: FanDuel, Odds Price: -120.0
#   Fighter A Avg Odds: -113.95833333333333
#   Fighter A Best Odds: -120.0 (Bookmaker: FanDuel)
#
# Fighter B: Valentina Shevchenko
#   Fighter B Odds:
#     Bookmaker: BetOnline.ag, Odds Price: -105.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -105.0
#     Bookmaker: Caesars, Odds Price: -105.0
#     Bookmaker: DraftKings, Odds Price: -105.0
#     Bookmaker: FanDuel, Odds Price: -108.0
#     Bookmaker: Bovada, Odds Price: -108.0
#     Bookmaker: BetOnline.ag, Odds Price: -105.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -105.0
#     Bookmaker: DraftKings, Odds Price: -105.0
#     Bookmaker: FanDuel, Odds Price: -115.0
#     Bookmaker: BetOnline.ag, Odds Price: -105.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -105.0
#     Bookmaker: Caesars, Odds Price: -105.0
#     Bookmaker: DraftKings, Odds Price: -105.0
#     Bookmaker: FanDuel, Odds Price: -115.0
#     Bookmaker: BetOnline.ag, Odds Price: -105.0
#     Bookmaker: BetRivers, Odds Price: -112.0
#     Bookmaker: LowVig.ag, Odds Price: -105.0
#     Bookmaker: Caesars, Odds Price: -105.0
#     Bookmaker: DraftKings, Odds Price: -115.0
#     Bookmaker: FanDuel, Odds Price: -106.0
#   Fighter B Avg Odds: -107.70833333333333
#   Fighter B Best Odds: -115.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-15T03:00:00Z
# Fighter A: Sean O'Malley
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -102.0
#     Bookmaker: Caesars, Odds Price: -120.0
#     Bookmaker: LowVig.ag, Odds Price: -110.0
#     Bookmaker: BetOnline.ag, Odds Price: -110.0
#     Bookmaker: BetRivers, Odds Price: 107.0
#     Bookmaker: Bovada, Odds Price: -108.0
#     Bookmaker: DraftKings, Odds Price: 114.0
#     Bookmaker: FanDuel, Odds Price: 108.0
#     Bookmaker: LowVig.ag, Odds Price: 114.0
#     Bookmaker: BetOnline.ag, Odds Price: 114.0
#     Bookmaker: BetRivers, Odds Price: 112.0
#   Fighter A Avg Odds: 0.75
#   Fighter A Best Odds: -120.0 (Bookmaker: Caesars)
#
# Fighter B: Merab Dvalishvili
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -110.0
#     Bookmaker: FanDuel, Odds Price: -125.0
#     Bookmaker: Caesars, Odds Price: 100.0
#     Bookmaker: LowVig.ag, Odds Price: -110.0
#     Bookmaker: BetOnline.ag, Odds Price: -110.0
#     Bookmaker: BetRivers, Odds Price: -132.0
#     Bookmaker: Bovada, Odds Price: -112.0
#     Bookmaker: DraftKings, Odds Price: -135.0
#     Bookmaker: FanDuel, Odds Price: -138.0
#     Bookmaker: LowVig.ag, Odds Price: -134.0
#     Bookmaker: BetOnline.ag, Odds Price: -134.0
#     Bookmaker: BetRivers, Odds Price: -137.0
#   Fighter B Avg Odds: -106.41666666666667
#   Fighter B Best Odds: -138.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-09-28T22:00:00Z
# Fighter A: Renato Moicano
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: 195.0
#     Bookmaker: LowVig.ag, Odds Price: 200.0
#     Bookmaker: BetOnline.ag, Odds Price: 200.0
#     Bookmaker: FanDuel, Odds Price: 186.0
#   Fighter A Avg Odds: 195.25
#   Fighter A Best Odds: 186.0 (Bookmaker: FanDuel)
#
# Fighter B: Benoit Saint-Denis
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: -238.0
#     Bookmaker: LowVig.ag, Odds Price: -235.0
#     Bookmaker: BetOnline.ag, Odds Price: -235.0
#     Bookmaker: FanDuel, Odds Price: -245.0
#   Fighter B Avg Odds: -238.25
#   Fighter B Best Odds: -245.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2024-10-06T03:00:00Z
# Fighter A: Alex Pereira
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -455.0
#     Bookmaker: LowVig.ag, Odds Price: -410.0
#     Bookmaker: BetOnline.ag, Odds Price: -410.0
#     Bookmaker: BetRivers, Odds Price: -455.0
#     Bookmaker: FanDuel, Odds Price: -520.0
#     Bookmaker: Caesars, Odds Price: -440.0
#     Bookmaker: DraftKings, Odds Price: -455.0
#     Bookmaker: LowVig.ag, Odds Price: -450.0
#     Bookmaker: BetOnline.ag, Odds Price: -450.0
#     Bookmaker: BetRivers, Odds Price: -455.0
#   Fighter A Avg Odds: -450.0
#   Fighter A Best Odds: -520.0 (Bookmaker: FanDuel)
#
# Fighter B: Khalil Rountree
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 350.0
#     Bookmaker: LowVig.ag, Odds Price: 340.0
#     Bookmaker: BetOnline.ag, Odds Price: 340.0
#     Bookmaker: BetRivers, Odds Price: 340.0
#     Bookmaker: FanDuel, Odds Price: 350.0
#     Bookmaker: Caesars, Odds Price: 340.0
#     Bookmaker: DraftKings, Odds Price: 350.0
#     Bookmaker: LowVig.ag, Odds Price: 350.0
#     Bookmaker: BetOnline.ag, Odds Price: 350.0
#     Bookmaker: BetRivers, Odds Price: 340.0
#   Fighter B Avg Odds: 345.0
#   Fighter B Best Odds: 340.0 (Bookmaker: LowVig.ag)
#
# ==================================================
#
# Event Date: 2024-10-19T22:00:00Z
# Fighter A: Francis Ngannou
#   Fighter A Odds:
#     Bookmaker: LowVig.ag, Odds Price: -280.0
#     Bookmaker: FanDuel, Odds Price: -350.0
#     Bookmaker: LowVig.ag, Odds Price: -280.0
#     Bookmaker: FanDuel, Odds Price: -350.0
#     Bookmaker: LowVig.ag, Odds Price: -280.0
#     Bookmaker: FanDuel, Odds Price: -430.0
#   Fighter A Avg Odds: -328.3333333333333
#   Fighter A Best Odds: -430.0 (Bookmaker: FanDuel)
#
# Fighter B: Renan Ferreira
#   Fighter B Odds:
#     Bookmaker: LowVig.ag, Odds Price: 240.0
#     Bookmaker: FanDuel, Odds Price: 250.0
#     Bookmaker: LowVig.ag, Odds Price: 240.0
#     Bookmaker: FanDuel, Odds Price: 250.0
#     Bookmaker: LowVig.ag, Odds Price: 240.0
#     Bookmaker: FanDuel, Odds Price: 300.0
#   Fighter B Avg Odds: 253.33333333333334
#   Fighter B Best Odds: 240.0 (Bookmaker: LowVig.ag)
#
# ==================================================
#
# Event Date: 2024-10-26T20:00:00Z
# Fighter A: Magomed Ankalaev
#   Fighter A Odds:
#     Bookmaker: BetOnline.ag, Odds Price: -270.0
#     Bookmaker: BetRivers, Odds Price: -295.0
#     Bookmaker: LowVig.ag, Odds Price: -270.0
#     Bookmaker: Caesars, Odds Price: -275.0
#     Bookmaker: DraftKings, Odds Price: -278.0
#     Bookmaker: FanDuel, Odds Price: -310.0
#     Bookmaker: BetOnline.ag, Odds Price: -270.0
#     Bookmaker: BetRivers, Odds Price: -295.0
#     Bookmaker: LowVig.ag, Odds Price: -270.0
#     Bookmaker: DraftKings, Odds Price: -278.0
#     Bookmaker: BetOnline.ag, Odds Price: -270.0
#     Bookmaker: BetRivers, Odds Price: -295.0
#     Bookmaker: LowVig.ag, Odds Price: -270.0
# ...
#     Bookmaker: BetUS, Odds Price: -250.0
#     Bookmaker: LowVig.ag, Odds Price: -235.0
#     Bookmaker: BetOnline.ag, Odds Price: -233.0
#     Bookmaker: TwinSpires, Odds Price: -275.0
#     Bookmaker: BetRivers, Odds Price: -275.0
#     Bookmaker: Unibet, Odds Price: -275.0
#     Bookmaker: DraftKings, Odds Price: -250.0
#     Bookmaker: William Hill (US), Odds Price: -250.0
#     Bookmaker: FanDuel, Odds Price: -280.0
#   Fighter B Avg Odds: -257.0
#   Fighter B Best Odds: -280.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2023-09-23T20:15:00Z
# Fighter A: Mohammed Usman
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -165.0
#     Bookmaker: WynnBET, Odds Price: -175.0
#     Bookmaker: BetUS, Odds Price: -160.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: BetOnline.ag, Odds Price: -169.0
#     Bookmaker: TwinSpires, Odds Price: -180.0
#     Bookmaker: BetRivers, Odds Price: -180.0
#     Bookmaker: Unibet, Odds Price: -180.0
#     Bookmaker: DraftKings, Odds Price: -180.0
#     Bookmaker: William Hill (US), Odds Price: -170.0
#     Bookmaker: FanDuel, Odds Price: -178.0
#   Fighter A Avg Odds: -173.36363636363637
#   Fighter A Best Odds: -180.0 (Bookmaker: TwinSpires)
#
# Fighter B: Jake Collier
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 135.0
#     Bookmaker: WynnBET, Odds Price: 145.0
#     Bookmaker: BetUS, Odds Price: 130.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: TwinSpires, Odds Price: 143.0
#     Bookmaker: BetRivers, Odds Price: 143.0
#     Bookmaker: Unibet, Odds Price: 143.0
#     Bookmaker: DraftKings, Odds Price: 150.0
#     Bookmaker: William Hill (US), Odds Price: 145.0
#     Bookmaker: FanDuel, Odds Price: 138.0
#   Fighter B Avg Odds: 142.0
#   Fighter B Best Odds: 130.0 (Bookmaker: BetUS)
#
# ==================================================
#
# Event Date: 2023-09-23T23:15:00Z
# Fighter A: Aj Fletcher
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: 160.0
#     Bookmaker: BetUS, Odds Price: 165.0
#     Bookmaker: LowVig.ag, Odds Price: 145.0
#     Bookmaker: BetOnline.ag, Odds Price: 145.0
#     Bookmaker: Unibet, Odds Price: 163.0
#     Bookmaker: TwinSpires, Odds Price: 163.0
#     Bookmaker: BetRivers, Odds Price: 163.0
#     Bookmaker: DraftKings, Odds Price: 164.0
#     Bookmaker: William Hill (US), Odds Price: 165.0
#     Bookmaker: FanDuel, Odds Price: 168.0
#   Fighter A Avg Odds: 160.1
#   Fighter A Best Odds: 145.0 (Bookmaker: LowVig.ag)
#
# Fighter B: Bryan Battle
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: -197.0
#     Bookmaker: BetUS, Odds Price: -195.0
#     Bookmaker: LowVig.ag, Odds Price: -170.0
#     Bookmaker: BetOnline.ag, Odds Price: -169.0
#     Bookmaker: Unibet, Odds Price: -205.0
#     Bookmaker: TwinSpires, Odds Price: -205.0
#     Bookmaker: BetRivers, Odds Price: -205.0
#     Bookmaker: DraftKings, Odds Price: -198.0
#     Bookmaker: William Hill (US), Odds Price: -195.0
#     Bookmaker: FanDuel, Odds Price: -220.0
#   Fighter B Avg Odds: -195.9
#   Fighter B Best Odds: -220.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2023-09-23T23:15:00Z
# Fighter A: Charles Jourdain
#   Fighter A Odds:
#     Bookmaker: Bovada, Odds Price: -125.0
#     Bookmaker: WynnBET, Odds Price: -125.0
#     Bookmaker: BetUS, Odds Price: -125.0
#     Bookmaker: LowVig.ag, Odds Price: -123.0
#     Bookmaker: BetOnline.ag, Odds Price: -123.0
#     Bookmaker: TwinSpires, Odds Price: -124.0
#     Bookmaker: BetRivers, Odds Price: -124.0
#     Bookmaker: Unibet, Odds Price: -124.0
#     Bookmaker: DraftKings, Odds Price: -130.0
#     Bookmaker: William Hill (US), Odds Price: -125.0
#     Bookmaker: FanDuel, Odds Price: -130.0
#   Fighter A Avg Odds: -125.27272727272727
#   Fighter A Best Odds: -130.0 (Bookmaker: DraftKings)
#
# Fighter B: Ricardo Ramos
#   Fighter B Odds:
#     Bookmaker: Bovada, Odds Price: 105.0
#     Bookmaker: WynnBET, Odds Price: 105.0
#     Bookmaker: BetUS, Odds Price: -105.0
#     Bookmaker: LowVig.ag, Odds Price: 103.0
#     Bookmaker: BetOnline.ag, Odds Price: 103.0
#     Bookmaker: TwinSpires, Odds Price: 100.0
#     Bookmaker: BetRivers, Odds Price: 100.0
#     Bookmaker: Unibet, Odds Price: 100.0
#     Bookmaker: DraftKings, Odds Price: 110.0
#     Bookmaker: William Hill (US), Odds Price: 105.0
#     Bookmaker: FanDuel, Odds Price: 102.0
#   Fighter B Avg Odds: 84.36363636363636
#   Fighter B Best Odds: -105.0 (Bookmaker: BetUS)
#
# ==================================================
#
# Event Date: 2023-09-23T23:15:00Z
# Fighter A: Michelle Waterson
#   Fighter A Odds:
#     Bookmaker: LowVig.ag, Odds Price: 212.0
#     Bookmaker: BetOnline.ag, Odds Price: 212.0
#     Bookmaker: Bovada, Odds Price: 245.0
#     Bookmaker: DraftKings, Odds Price: 245.0
#     Bookmaker: TwinSpires, Odds Price: 250.0
#     Bookmaker: BetRivers, Odds Price: 250.0
#     Bookmaker: Unibet, Odds Price: 250.0
#     Bookmaker: William Hill (US), Odds Price: 250.0
#     Bookmaker: FanDuel, Odds Price: 250.0
#   Fighter A Avg Odds: 240.44444444444446
#   Fighter A Best Odds: 212.0 (Bookmaker: LowVig.ag)
#
# Fighter B: Marina Rodriguez
#   Fighter B Odds:
#     Bookmaker: LowVig.ag, Odds Price: -252.0
#     Bookmaker: BetOnline.ag, Odds Price: -250.0
#     Bookmaker: Bovada, Odds Price: -325.0
#     Bookmaker: DraftKings, Odds Price: -305.0
#     Bookmaker: TwinSpires, Odds Price: -335.0
#     Bookmaker: BetRivers, Odds Price: -335.0
#     Bookmaker: Unibet, Odds Price: -335.0
#     Bookmaker: William Hill (US), Odds Price: -320.0
#     Bookmaker: FanDuel, Odds Price: -340.0
#   Fighter B Avg Odds: -310.77777777777777
#   Fighter B Best Odds: -340.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2023-09-24T00:45:00Z
# Fighter A: Dan Ige
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: 130.0
#     Bookmaker: LowVig.ag, Odds Price: 130.0
#     Bookmaker: BetOnline.ag, Odds Price: 130.0
#     Bookmaker: Bovada, Odds Price: 135.0
#     Bookmaker: DraftKings, Odds Price: 140.0
#     Bookmaker: WynnBET, Odds Price: 130.0
#     Bookmaker: Unibet, Odds Price: 135.0
#     Bookmaker: TwinSpires, Odds Price: 135.0
#     Bookmaker: BetRivers, Odds Price: 135.0
#     Bookmaker: William Hill (US), Odds Price: 135.0
#     Bookmaker: FanDuel, Odds Price: 132.0
#     Bookmaker: SuperBook, Odds Price: 135.0
#   Fighter A Avg Odds: 133.5
#   Fighter A Best Odds: 130.0 (Bookmaker: BetUS)
#
# Fighter B: Bryce Mitchell
#   Fighter B Odds:
#     Bookmaker: BetUS, Odds Price: -160.0
#     Bookmaker: LowVig.ag, Odds Price: -150.0
#     Bookmaker: BetOnline.ag, Odds Price: -149.0
#     Bookmaker: Bovada, Odds Price: -165.0
#     Bookmaker: DraftKings, Odds Price: -166.0
#     Bookmaker: WynnBET, Odds Price: -154.0
#     Bookmaker: Unibet, Odds Price: -167.0
#     Bookmaker: TwinSpires, Odds Price: -167.0
#     Bookmaker: BetRivers, Odds Price: -167.0
#     Bookmaker: William Hill (US), Odds Price: -160.0
#     Bookmaker: FanDuel, Odds Price: -170.0
#     Bookmaker: SuperBook, Odds Price: -155.0
#   Fighter B Avg Odds: -160.83333333333334
#   Fighter B Best Odds: -170.0 (Bookmaker: FanDuel)
#
# ==================================================
#
# Event Date: 2023-09-09T22:41:00Z
# Fighter A: Kevin Jousset
#   Fighter A Odds:
#     Bookmaker: WynnBET, Odds Price: -159.0
#     Bookmaker: LowVig.ag, Odds Price: -161.0
#     Bookmaker: BetOnline.ag, Odds Price: -161.0
#     Bookmaker: BetMGM, Odds Price: -160.0
#     Bookmaker: William Hill (US), Odds Price: -165.0
#     Bookmaker: DraftKings, Odds Price: -185.0
#     Bookmaker: BetRivers, Odds Price: -157.0
#     Bookmaker: TwinSpires, Odds Price: -157.0
#     Bookmaker: Unibet, Odds Price: -157.0
#     Bookmaker: SuperBook, Odds Price: -160.0
#     Bookmaker: FanDuel, Odds Price: -156.0
#     Bookmaker: Bovada, Odds Price: -170.0
#   Fighter A Avg Odds: -162.33333333333334
#   Fighter A Best Odds: -185.0 (Bookmaker: DraftKings)
#
# Fighter B: Kiefer Crosbie
#   Fighter B Odds:
#     Bookmaker: WynnBET, Odds Price: 135.0
#     Bookmaker: LowVig.ag, Odds Price: 141.0
#     Bookmaker: BetOnline.ag, Odds Price: 141.0
#     Bookmaker: BetMGM, Odds Price: 130.0
#     Bookmaker: William Hill (US), Odds Price: 140.0
#     Bookmaker: DraftKings, Odds Price: 154.0
#     Bookmaker: BetRivers, Odds Price: 128.0
#     Bookmaker: TwinSpires, Odds Price: 128.0
#     Bookmaker: Unibet, Odds Price: 128.0
#     Bookmaker: SuperBook, Odds Price: 140.0
#     Bookmaker: FanDuel, Odds Price: 132.0
#     Bookmaker: Bovada, Odds Price: 140.0
#   Fighter B Avg Odds: 136.41666666666666
#   Fighter B Best Odds: 128.0 (Bookmaker: BetRivers)
#
# ==================================================
#
# Event Date: 2023-09-09T23:11:00Z
# Fighter A: Shane Young
#   Fighter A Odds:
#     Bookmaker: WynnBET, Odds Price: -120.0
#     Bookmaker: BetOnline.ag, Odds Price: -115.0
#     Bookmaker: LowVig.ag, Odds Price: -115.0
#     Bookmaker: Bovada, Odds Price: -125.0
#     Bookmaker: BetMGM, Odds Price: -125.0
#     Bookmaker: William Hill (US), Odds Price: -115.0
#     Bookmaker: DraftKings, Odds Price: -122.0
#     Bookmaker: FanDuel, Odds Price: -120.0
#     Bookmaker: BetRivers, Odds Price: -132.0
#     Bookmaker: Unibet, Odds Price: -132.0
#     Bookmaker: TwinSpires, Odds Price: -132.0
#     Bookmaker: SuperBook, Odds Price: -115.0
#   Fighter A Avg Odds: -122.33333333333333
#   Fighter A Best Odds: -132.0 (Bookmaker: BetRivers)
#
# Fighter B: Gabriel Miranda
#   Fighter B Odds:
#     Bookmaker: WynnBET, Odds Price: 100.0
#     Bookmaker: BetOnline.ag, Odds Price: -105.0
#     Bookmaker: LowVig.ag, Odds Price: -105.0
#     Bookmaker: Bovada, Odds Price: 105.0
#     Bookmaker: BetMGM, Odds Price: 105.0
#     Bookmaker: William Hill (US), Odds Price: -105.0
#     Bookmaker: DraftKings, Odds Price: 102.0
#     Bookmaker: FanDuel, Odds Price: 102.0
#     Bookmaker: BetRivers, Odds Price: 106.0
#     Bookmaker: Unibet, Odds Price: 106.0
#     Bookmaker: TwinSpires, Odds Price: 106.0
#     Bookmaker: SuperBook, Odds Price: -105.0
#   Fighter B Avg Odds: 34.333333333333336
#   Fighter B Best Odds: -105.0 (Bookmaker: BetOnline.ag)
#
# ==================================================
#
# Event Date: 2023-09-09T23:41:00Z
# Fighter A: Mike Mathetha
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: 230.0
#     Bookmaker: Bovada, Odds Price: 260.0
#     Bookmaker: BetMGM, Odds Price: 260.0
#     Bookmaker: William Hill (US), Odds Price: 260.0
#     Bookmaker: FanDuel, Odds Price: 240.0
#     Bookmaker: SuperBook, Odds Price: 260.0
#   Fighter A Avg Odds: 251.66666666666666
#   Fighter A Best Odds: 230.0 (Bookmaker: BetUS)
#
# Fighter B: Charlie Radtke
#   Fighter B Odds:
#     Bookmaker: BetUS, Odds Price: -305.0
#     Bookmaker: Bovada, Odds Price: -325.0
#     Bookmaker: BetMGM, Odds Price: -350.0
#     Bookmaker: William Hill (US), Odds Price: -330.0
#     Bookmaker: FanDuel, Odds Price: -295.0
#     Bookmaker: SuperBook, Odds Price: -330.0
#   Fighter B Avg Odds: -322.5
#   Fighter B Best Odds: -350.0 (Bookmaker: BetMGM)
#
# ==================================================
#
# Event Date: 2023-09-10T00:16:00Z
# Fighter A: Landon Quinones
#   Fighter A Odds:
#     Bookmaker: BetRivers, Odds Price: 360.0
#     Bookmaker: Unibet, Odds Price: 360.0
#     Bookmaker: LowVig.ag, Odds Price: 370.0
#     Bookmaker: Bovada, Odds Price: 350.0
#     Bookmaker: BetOnline.ag, Odds Price: 370.0
#     Bookmaker: TwinSpires, Odds Price: 360.0
#     Bookmaker: BetMGM, Odds Price: 360.0
#     Bookmaker: William Hill (US), Odds Price: 380.0
#     Bookmaker: DraftKings, Odds Price: 360.0
#     Bookmaker: WynnBET, Odds Price: 370.0
#     Bookmaker: SuperBook, Odds Price: 375.0
#     Bookmaker: FanDuel, Odds Price: 370.0
#   Fighter A Avg Odds: 365.4166666666667
#   Fighter A Best Odds: 350.0 (Bookmaker: Bovada)
#
# Fighter B: Nasrat Haqparast
#   Fighter B Odds:
#     Bookmaker: BetRivers, Odds Price: -480.0
#     Bookmaker: Unibet, Odds Price: -480.0
#     Bookmaker: LowVig.ag, Odds Price: -469.0
#     Bookmaker: Bovada, Odds Price: -450.0
#     Bookmaker: BetOnline.ag, Odds Price: -476.0
#     Bookmaker: TwinSpires, Odds Price: -480.0
#     Bookmaker: BetMGM, Odds Price: -500.0
#     Bookmaker: William Hill (US), Odds Price: -500.0
#     Bookmaker: DraftKings, Odds Price: -470.0
#     Bookmaker: WynnBET, Odds Price: -476.0
#     Bookmaker: SuperBook, Odds Price: -500.0
#     Bookmaker: FanDuel, Odds Price: -480.0
#   Fighter B Avg Odds: -480.0833333333333
#   Fighter B Best Odds: -500.0 (Bookmaker: BetMGM)
#
# ==================================================
#
# Event Date: 2023-09-10T00:45:00Z
# Fighter A: Jamie Mullarkey
#   Fighter A Odds:
#     Bookmaker: BetOnline.ag, Odds Price: -263.0
#     Bookmaker: LowVig.ag, Odds Price: -261.0
#     Bookmaker: DraftKings, Odds Price: -305.0
#     Bookmaker: TwinSpires, Odds Price: -275.0
#     Bookmaker: Unibet, Odds Price: -275.0
#     Bookmaker: BetRivers, Odds Price: -275.0
#     Bookmaker: Bovada, Odds Price: -285.0
#     Bookmaker: WynnBET, Odds Price: -263.0
#     Bookmaker: BetMGM, Odds Price: -275.0
#     Bookmaker: William Hill (US), Odds Price: -270.0
#     Bookmaker: FanDuel, Odds Price: -255.0
#     Bookmaker: SuperBook, Odds Price: -270.0
#   Fighter A Avg Odds: -272.6666666666667
#   Fighter A Best Odds: -305.0 (Bookmaker: DraftKings)
#
# Fighter B: John Makdessi
#   Fighter B Odds:
#     Bookmaker: BetOnline.ag, Odds Price: 221.0
#     Bookmaker: LowVig.ag, Odds Price: 221.0
#     Bookmaker: DraftKings, Odds Price: 245.0
#     Bookmaker: TwinSpires, Odds Price: 210.0
#     Bookmaker: Unibet, Odds Price: 210.0
#     Bookmaker: BetRivers, Odds Price: 210.0
#     Bookmaker: Bovada, Odds Price: 225.0
#     Bookmaker: WynnBET, Odds Price: 218.0
#     Bookmaker: BetMGM, Odds Price: 225.0
#     Bookmaker: William Hill (US), Odds Price: 220.0
#     Bookmaker: FanDuel, Odds Price: 210.0
#     Bookmaker: SuperBook, Odds Price: 220.0
#   Fighter B Avg Odds: 219.58333333333334
#   Fighter B Best Odds: 210.0 (Bookmaker: TwinSpires)
#
# ==================================================
#
# Event Date: 2023-09-10T01:15:00Z
# Fighter A: Jack Jenkins
#   Fighter A Odds:
#     Bookmaker: DraftKings, Odds Price: -225.0
#     Bookmaker: BetUS, Odds Price: -200.0
#     Bookmaker: TwinSpires, Odds Price: -210.0
#     Bookmaker: Unibet, Odds Price: -210.0
#     Bookmaker: BetRivers, Odds Price: -210.0
#     Bookmaker: Bovada, Odds Price: -225.0
#     Bookmaker: LowVig.ag, Odds Price: -202.0
#     Bookmaker: William Hill (US), Odds Price: -205.0
#     Bookmaker: FanDuel, Odds Price: -200.0
#     Bookmaker: WynnBET, Odds Price: -204.0
#     Bookmaker: BetOnline.ag, Odds Price: -200.0
#     Bookmaker: BetMGM, Odds Price: -200.0
#     Bookmaker: SuperBook, Odds Price: -210.0
#   Fighter A Avg Odds: -207.76923076923077
#   Fighter A Best Odds: -225.0 (Bookmaker: DraftKings)
#
# Fighter B: Jose Mariscal
#   Fighter B Odds:
#     Bookmaker: DraftKings, Odds Price: 185.0
#     Bookmaker: BetUS, Odds Price: 165.0
#     Bookmaker: TwinSpires, Odds Price: 165.0
#     Bookmaker: Unibet, Odds Price: 165.0
#     Bookmaker: BetRivers, Odds Price: 165.0
#     Bookmaker: Bovada, Odds Price: 185.0
#     Bookmaker: LowVig.ag, Odds Price: 172.0
#     Bookmaker: William Hill (US), Odds Price: 170.0
#     Bookmaker: FanDuel, Odds Price: 168.0
#     Bookmaker: WynnBET, Odds Price: 172.0
#     Bookmaker: BetOnline.ag, Odds Price: 172.0
#     Bookmaker: BetMGM, Odds Price: 165.0
#     Bookmaker: SuperBook, Odds Price: 175.0
#   Fighter B Avg Odds: 171.07692307692307
#   Fighter B Best Odds: 165.0 (Bookmaker: BetUS)
#
# ==================================================
#
# Event Date: 2023-09-10T01:45:00Z
# Fighter A: Carlos Ulberg
#   Fighter A Odds:
#     Bookmaker: BetUS, Odds Price: -305.0
#     Bookmaker: TwinSpires, Odds Price: -315.0
#     Bookmaker: Unibet, Odds Price: -315.0
#     Bookmaker: BetRivers, Odds Price: -315.0
#     Bookmaker: Bovada, Odds Price: -285.0
#     Bookmaker: WynnBET, Odds Price: -263.0
#     Bookmaker: LowVig.ag, Odds Price: -260.0
#     Bookmaker: DraftKings, Odds Price: -278.0
#     Bookmaker: BetOnline.ag, Odds Price: -263.0
#     Bookmaker: William Hill (US), Odds Price: -300.0
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
